# %% [markdown]
# # Implement RULES to extract related adjectives then Implement visualization

# %% [markdown]
# # SETUP

# %%
import pandas as pd
import numpy as np
import nltk
import time
import spacy
import pickle
sp_md = spacy.load('en_core_web_md')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords

# %% [markdown]
# # Load data

# %%
wdir="steam/"
wdir="metacritic/"
wdir="AM_videogames/"
df = pd.read_pickle(wdir+"1_df.pkl")
print(df.shape)
print(df.groupby('game_title').review_id.nunique())
df = df.sample(frac=1).reset_index(drop=True) # random sampling and resetting index

df.head(1)
# Out:
# (2585, 4)
# game_title
# God of War III                    601
# Mario Kart                        472
# StarCraft II: Wings of Liberty    370
# The Last of Us                    549
# diablo III                        593
# Name: review_id, dtype: int64
#    review_id  game_title                   review_text  score
# 0      50213  Mario Kart  fun game for me and the kids    4.0

# %% [markdown]
# # Preprocessing reviews

# %% [markdown]
# ## split reviews in sentences + compute sentence polarities

# %%
from nltk import tokenize # del
from sentiment_polarity import * 
# nltk.download('punkt') # doesnt re download is exists ) 
from stopwords import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# %%timeit -n 1 -r 1 
sentences_df = extract_sentences(df)


sentences_df['vader_polarity'] = sentences_df["sentence"].apply(getVaderPolarity)


print(sentences_df.shape)
sentences_df.to_pickle(wdir+"2_df.pkl")

# sentences_df.head(1)
# Out:
# 2585
# 100% processed
# (15252, 4)

# %% [markdown]
# ## Stop words

# %%
# %%timeit -n 1 -r 1 # number of loop
sentences_df = pd.read_pickle(wdir+"2_df.pkl")

games_list=df['game_title'].unique()

proc_sent_df = remove_stop_prefixes(sentences_df,games_list)
print(proc_sent_df.shape)


proc_sent_df.to_pickle(wdir+"3_df.pkl")
proc_sent_df.head()
games_list
# Out:
# 100% processed       % processed    % processed    % processed
# (15252, 5)
# array(['Mario Kart', 'God of War III', 'StarCraft II: Wings of Liberty',
#        'The Last of Us', 'diablo III'], dtype=object)

# %% [markdown]
# ## POS + Lemmatization
# TB and WN, 30 sec for 20k sentences
# SP is way longer, 60x longer (30 min )

# %%
from POSLemma import *
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# # %%timeit -n 1 -r 1 # number of loop
# POSLemmaChoice ="SP" # WN TB SP
# proc_sent_df = pd.read_pickle(wdir+"3_df.pkl")


# POSLemma_sent_df = POSLemma_extractor(proc_sent_df,POSLemmaChoice)


# ## Save POSLemma Dataframe
# POSLemma_sent_df.to_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
# print(POSLemma_sent_df.head(5))
# print(POSLemma_sent_df.shape)

# %% [markdown]
# # Create FOPs and compute importance

# %% [markdown]
# ## FOPs extraction

# %%
from FOPs import *

# %%
# %%timeit -n 1 -r 1 # number of loop
"""
input: Dataframe of sentences with POS tags, chosen POS method and game title. 
Output: a dictionary of FOPs with their occurence and importance(occurence*sentence polarity) , structured as: 
        {"feature1": 
            {"opinion1": 
                { "count": value, 
                "importance":value } }
            {"opinion2": 
                { "count": value, 
                "importance":value } }
"""

POSLemmaChoice="SP"
FOPs_df = pd.read_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
# print(FOPs_df.groupby('game_title').review_id.nunique())
games_list=df['game_title'].unique()
print(games_list)
chosen_game="diablo III"


FOPs_game_dic = extract_all_FOPs(FOPs_df, chosen_game)

save_FOPs_dic_csv(FOPs_game_dic, wdir,chosen_game )
# Out:
# ['Mario Kart' 'God of War III' 'StarCraft II: Wings of Liberty'
#  'The Last of Us' 'diablo III']
# 4864  sentences for the game  diablo III
# 99  % processed

# %% [markdown]
# ## count and importance FOPs results
# Can also select only negatives or only positive, select specific feature(s)

# %%
FOPs_df = pd.read_csv(wdir+chosen_game+"_FOPs.csv")  # Creation of the dataframe 

FOPs_df["count"] = FOPs_df["count"]/2
FOPs_df["importance"] = FOPs_df["importance"]/2
FOPs_df["importance"] = FOPs_df["importance"]/FOPs_df["importance"].max()
FOPs_df["polarity"] = FOPs_df["importance"]/FOPs_df["count"]
FOPs_df["importance"]= abs(FOPs_df["importance"])
FOPs_df = FOPs_df.sort_values('importance', ascending=False)
FOPs_df=FOPs_df.reset_index(drop=True)
# maxCount = FOPs_df.iloc[0]["count"]
# FOPs_df = FOPs_df.loc[FOPs_df["count"] > maxCount/20]
# FOPs_df = FOPs_df.sort_values('importance', ascending=False)
print(FOPs_df.shape)
FOPs_df.head(20)
# Out:
# (23005, 5)
#           feature   opinion  count  importance  polarity
# 0           items  lettered   22.0    1.000000  0.045455
# 1           items    better   11.0    0.640998  0.058273
# 2         auction      good   10.0    0.456262  0.045626
# 3           house      good   10.0    0.456262  0.045626
# 4            time      good    8.0    0.456199  0.057025
# 5            farm   shotted    6.0    0.451662 -0.075277
# 6             fun   shotted    6.0    0.451662 -0.075277
# 7        graphics      good   10.0    0.447559  0.044756
# 8        gameplay  terrible    6.0    0.432251  0.072042
# 9         bonuses       set    6.0    0.428084  0.071347
# 10  customization        ah    9.0    0.414591 -0.046066
# 11       gameplay      good    8.0    0.413992  0.051749
# 12          items    yellow    8.0    0.412642  0.051580
# 13          items     green    8.0    0.402029  0.050254
# 14           gear    better    7.0    0.381040  0.054434
# 15       graphics    better    8.0    0.372432  0.046554
# 16         people      hard    5.0    0.369110 -0.073822
# 17            buy        ah    8.0    0.363176 -0.045397
# 18          items     white    7.0    0.358134  0.051162
# 19          items     brown    7.0    0.358134  0.051162

# %%
FOPs_df = FOPs_df.sort_values('count', ascending=False)
FOPs_df=FOPs_df.reset_index(drop=True)

FOPs_df.head(5)
# Out:
#    feature   opinion  count  importance  polarity
# 0   player    single    102      8.7512 -0.085796
# 1    money      real     78      0.4520 -0.005795
# 2  auction      real     56      3.0648 -0.054729
# 3    house      real     52      2.7552 -0.052985
# 4    items  lettered     44     25.3464  0.576055

# %%
sentence="The sound of the speakers could be better"
def FOP_parser_sentence(sentence,sp_md,FOPs_game_dic):
    prod_pronouns=["it", "they", "this"]
    doc=sp_md(sentence)
    #print("--- SPACY : Doc loaded ---")

    ## FIRST RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    ## RULE = M is child of A with a relationshio of amod
    rule1_pairs = []
    rule2_pairs = []
    rule3_pairs = []
    rule4_pairs = []
    rule5_pairs = []
    rule6_pairs = []

    for token in doc:
        A = "999999"
        M = "999999"
        if token.dep_ == "amod" and not token.is_stop:
            M = token.text
            A = token.head.text

            # add adverbial modifier of adjective (e.g. 'most comfortable headphones')
            M_children = token.children
            for child_m in M_children:
                if(child_m.dep_ == "advmod"):
                    M_hash = child_m.text
                    M = M_hash + " " + M
                    break

            # negation in adjective, the "no" keyword is a 'det' of the noun (e.g. no interesting characters)
            A_children = token.head.children
            Msent=M
            for child_a in A_children:
                if(child_a.dep_ == "det" and child_a.text == 'no'):
                    neg_prefix = 'not'
                    Msent = neg_prefix + " " + M
                    break

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict1 = {"noun" : A, "adj" : M, "rule" : 1, "polarity" : getVaderPolarity(Msent)}
            rule1_pairs.append(dict1)

        # print("--- SPACY : Rule 1 Done ---")

        # # SECOND RULE OF DEPENDANCY PARSE -
        # # M - Sentiment modifier || A - Aspect
        # Direct Object - A is a child of something with relationship of nsubj, while
        # M is a child of the same something with relationship of dobj
        # Assumption - A verb will have only one NSUBJ and DOBJ
        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if((child.dep_ == "dobj" and child.pos_ == "ADJ") and not child.is_stop):
                M = child.text
                #check_spelling(child.text)

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True
        Msent=M
        if (add_neg_pfx and M != "999999"):
            Msent = neg_prefix + " " + M
        
        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict2 = {"noun" : A, "adj" : M, "rule" : 2, "polarity" : getVaderPolarity(Msent)}
            rule2_pairs.append(dict2)




        # print("--- SPACY : Rule 2 Done ---")

        ## THIRD RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect
        ## Adjectival Complement - A is a child of something with relationship of nsubj, while
        ## M is a child of the same something with relationship of acomp
        ## Assumption - A verb will have only one NSUBJ and DOBJ
        ## "The sound of the speakers would be better. The sound of the speakers could be better" - handled using AUX dependency

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "acomp" and not child.is_stop):
                M = child.text

            # example - 'this could have been better' -> (this, not better)
            if(child.dep_ == "aux" and child.tag_ == "MD"):
                neg_prefix = "not"
                add_neg_pfx = True

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True
        Msent=M
        if (add_neg_pfx and M != "999999"):
            Msent = neg_prefix + " " + M
                #check_spelling(child.text)

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict3 = {"noun" : A, "adj" : M, "rule" : 3, "polarity" : getVaderPolarity(Msent)}
            rule3_pairs.append(dict3)
            #rule3_pairs.append((A, M, getVaderPolarity(M),3))
    # print("--- SPACY : Rule 3 Done ---")

        ## FOURTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect

        #Adverbial modifier to a passive verb - A is a child of something with relationship of nsubjpass, while
        # M is a child of the same something with relationship of advmod

        #Assumption - A verb will have only one NSUBJ and DOBJ

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if((child.dep_ == "nsubjpass" or child.dep_ == "nsubj") and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "advmod" and not child.is_stop):
                M = child.text
                M_children = child.children
                for child_m in M_children:
                    if(child_m.dep_ == "advmod"):
                        M_hash = child_m.text
                        M = M_hash + " " + child.text
                        break
                #check_spelling(child.text)

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True
        
        Msent=M
        if (add_neg_pfx and M != "999999"):
            Msent = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict4 = {"noun" : A, "adj" : M, "rule" : 4, "polarity" : getVaderPolarity(Msent)}
            rule4_pairs.append(dict4)
            #rule4_pairs.append((A, M,getVaderPolarity(M),4)) # )

    # print("--- SPACY : Rule 4 Done ---")


        ## FIFTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect

        #Complement of a copular verb - A is a child of M with relationship of nsubj, while
        # M has a child with relationship of cop

        #Assumption - A verb will have only one NSUBJ and DOBJ

        children = token.children
        A = "999999"
        buf_var = "999999"
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "cop" and not child.is_stop):
                buf_var = child.text
                #check_spelling(child.text)

        if(A != "999999" and buf_var != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict5 = {"noun" : A, "adj" : token.text, "rule" : 5, "polarity" : getVaderPolarity(M)}
            rule5_pairs.append(dict5)
            #rule5_pairs.append((A, token.text,getVaderPolarity(token.text),5))

    # print("--- SPACY : Rule 5 Done ---")

        ## SIXTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect
        ## Example - "It ok", "ok" is INTJ (interjections like bravo, great etc)

        children = token.children
        A = "999999"
        M = "999999"
        if(token.pos_ == "INTJ" and not token.is_stop):
            for child in children :
                if(child.dep_ == "nsubj" and not child.is_stop):
                    A = child.text
                    M = token.text
                    # check_spelling(child.text)

            #rule6_pairs.append((A, M,getVaderPolarity(M),6))

    # print("--- SPACY : Rule 6 Done ---")

    ## SEVENTH RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    ## ATTR - link between a verb like 'be/seem/appear' and its complement
    ## Example: 'this is garbage' -> (this, garbage)

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if((child.dep_ == "attr") and not child.is_stop):
                M = child.text
                #check_spelling(child.text)
            
            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True
        
        Msent=M
        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict6 = {"noun" : A, "adj" : M, "rule" : 6, "polarity" : getVaderPolarity(Msent)}
            rule6_pairs.append(dict6)
            #rule7_pairs.append((A, M,getVaderPolarity(M),7))



    #print("--- SPACY : Rules Done ---")


    aspects = []

    aspects = rule1_pairs + rule2_pairs + rule3_pairs +rule4_pairs +rule5_pairs + rule6_pairs

    # replace all instances of "it", "this" and "they" with "product"
    #aspects = [(A,M,P,r) if A not in prod_pronouns else ("product",M,P,r) for A,M,P,r in aspects ]

    # dic = {"review_id" : review_id , "aspect_pairs" : aspects, "review_marketplace" : review_marketplace
    # , "customer_id" : customer_id, "product_id" : product_id, "product_parent" : product_parent,
    # "product_title" : product_title, "product_category" : product_category, "date" : date, "star_rating" : star_rating, "url" : url}
    
    for aspect in aspects:
        feature=aspect["noun"].lower()
        opinion=aspect["adj"].lower() 
        opinion=opinion.split(" ")
        opinion= "_".join(opinion)
        polarity= aspect["polarity"]

    # Count FOPs and weighted importance
        if feature not in FOPs_game_dic:
            FOPs_game_dic[feature]={} 

        if opinion not in FOPs_game_dic[feature]:
            FOPs_game_dic[feature][opinion]={}
            FOPs_game_dic[feature][opinion]["count"]=1 # frequency, number of occurence of the pair
            FOPs_game_dic[feature][opinion]["importance"]=polarity # frequency weighted with polarity of the sentence containing the occurence
        else:
            FOPs_game_dic[feature][opinion]["count"]+=1
            FOPs_game_dic[feature][opinion]["importance"]+=polarity


    return aspects, FOPs_game_dic

# %%
def FOPs_parser_all(FOPs_df, chosen_game):

    FOPs_df=FOPs_df.loc[FOPs_df['game_title'] ==chosen_game ]
    FOPs_df=FOPs_df.reset_index(drop=True)

    df_len=len(FOPs_df.index)
    print(df_len, " sentences for the game ",chosen_game )
    percent=int(df_len/10)
    FOPs_sent_dic={} # FOPs in each sentence 
    FOPs_game_dic={} # FOPs all data-wise
    for index, row in FOPs_df.iterrows():
    #     if index==2:
    #         break
        if (index%percent)==1:
            print(int(index/df_len*100) , " % processed", end="\r", flush=True)

        sent_FOPs, FOPs_game_dic = FOP_parser_sentence(row["sentence"], sp_md, FOPs_game_dic)

    return FOPs_game_dic

# %%
# %%timeit -n 1 -r 1 # number of loop
"""
input: Dataframe of sentences with POS tags, chosen POS method and game title. 
Output: a dictionary of FOPs with their occurence and importance(occurence*sentence polarity) , structured as: 
        {"feature1": 
            {"opinion1": 
                { "count": value, 
                "importance":value } }
            {"opinion2": 
                { "count": value, 
                "importance":value } }
"""

POSLemmaChoice="SP"
FOPs_df = pd.read_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
# print(FOPs_df.groupby('game_title').review_id.nunique())
games_list=df['game_title'].unique()
print(games_list)
chosen_game="diablo III"


FOPs_game_dic = FOPs_parser_all(FOPs_df, chosen_game)

save_FOPs_dic_csv(FOPs_game_dic, wdir,chosen_game+"_parser" )
# Out:
# ['Mario Kart' 'God of War III' 'StarCraft II: Wings of Liberty'
#  'The Last of Us' 'diablo III']
# 4864  sentences for the game  diablo III
# 99  % processed

# %%
save_FOPs_dic_csv(FOPs_game_dic, wdir,chosen_game+"_parser" )

# %%
FOPs_game_dic
# Out:
# {'sign': {'ridiculous': {'count': 2, 'importance': -0.7224}},
#  'iii': {'garbage': {'count': 2, 'importance': 0.0},
#   'truly': {'count': 2, 'importance': 0.8808},
#   'so_far': {'count': 2, 'importance': 0.0},
#   'game': {'count': 8, 'importance': 0.0},
#   'essentially': {'count': 2, 'importance': 0.0},
#   'disappointment': {'count': 2, 'importance': -1.0212},
#   'worth': {'count': 2, 'importance': 0.4526},
#   'linear': {'count': 2, 'importance': 0.0},
#   'probably': {'count': 2, 'importance': 0.0},
#   'milder': {'count': 2, 'importance': 0.0},
#   'excellent': {'count': 2, 'importance': 1.1438}},
#  'game': {'decent': {'count': 4, 'importance': 0.0},
#   'repetitive': {'count': 2, 'importance': -0.5},
#   'boring': {'count': 6, 'importance': -1.9092},
#   'embarrassingly_bad': {'count': 2, 'importance': -1.4702},
#   'disappointment': {'count': 2, 'importance': -1.0212},
#   'able': {'count': 2, 'importance': 0.0},
#   'great': {'count': 58, 'importance': 36.244199999999985},
#   'better': {'count': 8, 'importance': 1.96},
#   'par': {'count': 2, 'importance': 0.0},
#   'dumbed': {'count': 2, 'importance': -0.68},
#   'fun': {'count': 36, 'importance': 14.730000000000002},
#   'perfect': {'count': 6, 'importance': 1.3706},
#   'cool': {'count': 4, 'importance': 1.2728},
#   'smoothly': {'count': 2, 'importance': 0.0},
#   'previous': {'count': 2, 'importance': 0.0},
#   'tedious': {'count': 2, 'importance': 0.0},
#   'bad': {'count': 8, 'importance': -2.3918},
#   'results': {'count': 2, 'importance': 0.0},
#   'continually': {'count': 2, 'importance': 0.0},
#   'dud': {'count': 2, 'importance': -0.5},
#   'pretty_good': {'count': 2, 'importance': 1.4538},
#   'good': {'count': 35, 'importance': 15.414000000000009},
#   'funnest': {'count': 4, 'importance': 2.3976},
#   'truly_incredible': {'count': 2, 'importance': 0.8808},
#   'entire': {'count': 6, 'importance': 0.0},
#   'clear': {'count': 2, 'importance': 0.7636},
#   'favorite': {'count': 4, 'importance': 1.8352},
#   'best': {'count': 2, 'importance': 1.2738},
#   'ok': {'count': 6, 'importance': 1.776},
#   'fast': {'count': 2, 'importance': 0.0},
#   'most_hyped': {'count': 2, 'importance': 0.0},
#   'horrible': {'count': 2, 'importance': -1.0846},
#   'very_stable': {'count': 2, 'importance': 0.7194},
#   'terrible': {'count': 2, 'importance': 0.7448},
#   'awesome': {'count': 8, 'importance': 4.999200000000001},
#   'ready': {'count': 2, 'importance': -0.551},
#   'beautiful': {'count': 4, 'importance': 2.3976},
#   'worth': {'count': 4, 'importance': 0.1136},
#   'lot': {'count': 4, 'importance': 0.0},
#   'excellent': {'count': 2, 'importance': 1.1438},
#   'smashing': {'count': 2, 'importance': 0.0},
#   'lots': {'count': 2, 'importance': 0.0},
#   'worst': {'count': 2, 'importance': -1.2498},
#   'fastest': {'count': 2, 'importance': 0.0},
#   'addictive': {'count': 2, 'importance': 0.0},
#   'very_fun': {'count': 4, 'importance': 2.2252},
#   'game': {'count': 4, 'importance': 0.0},
#   'really_good': {'count': 2, 'importance': 0.9854},
#   'unplayable': {'count': 6, 'importance': 0.0},
#   'worthy': {'count': 2, 'importance': 0.8808},
#   'hollow': {'count': 2, 'importance': 0.0},
#   'new': {'count': 6, 'importance': 0.0},
#   'unopened': {'count': 2, 'importance': 0.0},
#   'very_addicting': {'count': 2, 'importance': 0.0},
#   'let': {'count': 2, 'importance': 0.0},
#   "n't_liner": {'count': 2, 'importance': 0.0},
#   'solo': {'count': 2, 'importance': 0.0},
#   'pretty': {'count': 2, 'importance': 0.9878},
#   'playable': {'count': 4, 'importance': 0.0},
#   'late': {'count': 2, 'importance': 0.0},
#   'lastly': {'count': 4, 'importance': 0.0},
#   'immediately': {'count': 2, 'importance': 0.0},
#   'very_deep': {'count': 2, 'importance': 0.0},
#   'exact': {'count': 2, 'importance': 0.0},
#   'easy': {'count': 2, 'importance': 0.8808},
#   'big': {'count': 4, 'importance': 0.0},
#   'originally': {'count': 2, 'importance': 0.0},
#   'laggy': {'count': 2, 'importance': 0.0},
#   'diablo': {'count': 2, 'importance': 0.0},
#   'actually': {'count': 6, 'importance': 0.0},
#   'future': {'count': 2, 'importance': 0.0},
#   'similar': {'count': 2, 'importance': 0.0},
#   'broken': {'count': 2, 'importance': -0.9534},
#   'cakewalk': {'count': 2, 'importance': 0.0},
#   'smooth': {'count': 2, 'importance': 0.0},
#   'perfectly': {'count': 2, 'importance': 1.2738},
#   'different': {'count': 2, 'importance': 0.0},
#   'poorly': {'count': 2, 'importance': 0.0},
#   'hard': {'count': 2, 'importance': -0.2054},
#   'sluggish': {'count': 2, 'importance': -0.8038},
#   'cheaper': {'count': 2, 'importance': 0.0},
#   'amazing': {'count': 4, 'importance': 2.3436},
#   'not_perfection': {'count': 2, 'importance': 1.1438},
#   'very_different': {'count': 2, 'importance': 0.0},
#   'grind': {'count': 2, 'importance': 0.0},
#   'single': {'count': 8, 'importance': 0.0},
#   'brilliant': {'count': 2, 'importance': 1.1718},
#   'probably': {'count': 2, 'importance': 0.0},
#   'hack': {'count': 2, 'importance': 0.0},
#   'frustrating': {'count': 2, 'importance': -0.8808},
#   'of_course': {'count': 2, 'importance': 0.0},
#   'current': {'count': 2, 'importance': 0.0},
#   'very_best': {'count': 2, 'importance': 1.3394},
#   'darn': {'count': 2, 'importance': 0.0},
#   'redundant': {'count': 2, 'importance': 0.0},
#   'quickly': {'count': 2, 'importance': 0.0},
#   'house': {'count': 2, 'importance': 0.0},
#   'significantly_harder': {'count': 2, 'importance': 0.0},
#   'short': {'count': 2, 'importance': 0.0},
#   'online': {'count': 4, 'importance': 0.0},
#   'linear': {'count': 2, 'importance': 0.0},
#   'very_good': {'count': 2, 'importance': 0.9854},
#   'very_entertaining': {'count': 2, 'importance': 0.9854},
#   'flawlessly': {'count': 2, 'importance': 0.4046},
#   'terrific': {'count': 2, 'importance': 0.9534},
#   'basically': {'count': 2, 'importance': 0.0},
#   'free': {'count': 2, 'importance': 1.0212},
#   'travesty': {'count': 2, 'importance': -1.1438},
#   'solid': {'count': 2, 'importance': 0.3062},
#   'simple': {'count': 2, 'importance': 0.0},
#   'ridiculous': {'count': 2, 'importance': -0.7224},
#   'wonderful': {'count': 2, 'importance': 1.1438},
#   'potentially_great': {'count': 2, 'importance': 1.2498},
#   'totally': {'count': 2, 'importance': 0.0},
#   'lame': {'count': 2, 'importance': -0.843},
#   'rather_fun': {'count': 2, 'importance': 1.0212}},
#  'ii': {'brilliant': {'count': 2, 'importance': 1.1718},
#   'game': {'count': 2, 'importance': 0.0},
#   'wake': {'count': 2, 'importance': 0.0}},
#  'team': {'horribly_disrespectful': {'count': 2, 'importance': -1.0534},
#   'actually': {'count': 2, 'importance': 0.0}},
#  'drops': {'ridiculously_bad': {'count': 2, 'importance': -1.4192},
#   'overall': {'count': 2, 'importance': 0.0},
#   'random': {'count': 2, 'importance': 0.0},
#   'good': {'count': 4, 'importance': 0.19840000000000008},
#   'legendary': {'count': 4, 'importance': 0.0},
#   'tightly': {'count': 2, 'importance': 0.0},
#   'poor': {'count': 4, 'importance': -1.9068},
#   'useful': {'count': 2, 'importance': 0.8808},
#   'noticeably': {'count': 2, 'importance': 0.0},
#   'low': {'count': 2, 'importance': -0.5464}},
#  'servers': {'terribly_laggy': {'count': 2, 'importance': -1.1148},
#   'laggy': {'count': 2, 'importance': 0.0},
#   'unreliable': {'count': 2, 'importance': 0.0},
#   'terrible': {'count': 2, 'importance': -0.9534},
#   'heavily_flooded': {'count': 2, 'importance': 0.0},
#   'soon': {'count': 2, 'importance': 0.0},
#   'vast': {'count': 2, 'importance': 0.0},
#   'connection': {'count': 2, 'importance': 0.0}},
#  'house': {'real': {'count': 18, 'importance': 0.0},
#   'broken': {'count': 2, 'importance': -0.9534},
#   'addicting': {'count': 2, 'importance': 0.0},
#   'nice': {'count': 2, 'importance': -0.6504},
#   'awesome': {'count': 2, 'importance': 1.2498},
#   'better': {'count': 2, 'importance': 0.8808},
#   'right': {'count': 2, 'importance': 0.0},
#   'offline': {'count': 2, 'importance': -0.256},
#   'online': {'count': 2, 'importance': 0.0},
#   'instant': {'count': 2, 'importance': 0.0},
#   'completely': {'count': 2, 'importance': 0.0},
#   'much_debated': {'count': 2, 'importance': 0.0},
#   'longer': {'count': 2, 'importance': 0.0}},
#  'items': {'better': {'count': 8, 'importance': 3.5231999999999997},
#   'good': {'count': 6, 'importance': 2.6424},
#   'yellow': {'count': 4, 'importance': 0.0},
#   'constant': {'count': 2, 'importance': 0.0},
#   'changing': {'count': 2, 'importance': 0.0},
#   'rare': {'count': 4, 'importance': 0.0},
#   'set': {'count': 2, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0},
#   'virtual': {'count': 4, 'importance': 0.0},
#   'necessary': {'count': 2, 'importance': 0.0},
#   'orange': {'count': 2, 'importance': 0.0},
#   'illegitimate': {'count': 2, 'importance': 0.0},
#   'blue': {'count': 6, 'importance': 0.0},
#   'breaking': {'count': 2, 'importance': 0.0},
#   'total': {'count': 2, 'importance': 0.0},
#   'identical': {'count': 2, 'importance': 0.0},
#   'juicy': {'count': 2, 'importance': 0.0},
#   'normal': {'count': 2, 'importance': 0.0},
#   'white': {'count': 4, 'importance': 0.0},
#   'lettered': {'count': 10, 'importance': 0.0},
#   'legendary': {'count': 2, 'importance': 0.0},
#   'green': {'count': 2, 'importance': 0.0},
#   'junk': {'count': 2, 'importance': 0.0},
#   'sharable': {'count': 2, 'importance': 0.0},
#   'magic': {'count': 2, 'importance': 0.0},
#   'hot': {'count': 2, 'importance': 0.0},
#   'so_fast': {'count': 2, 'importance': 0.0},
#   'reasonably_listed': {'count': 2, 'importance': 0.0},
#   'garbage': {'count': 2, 'importance': 0.0},
#   'pathetic': {'count': 2, 'importance': -1.1438}},
#  'gear': {'better': {'count': 8, 'importance': 3.5231999999999997},
#   'useful': {'count': 2, 'importance': 0.8808},
#   'expensive': {'count': 2, 'importance': 0.0},
#   'really_good': {'count': 2, 'importance': 0.9854},
#   'massively_powerful': {'count': 2, 'importance': 0.843},
#   'awesome': {'count': 4, 'importance': 2.4996},
#   'ish': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'best': {'count': 2, 'importance': 1.2738},
#   'rare': {'count': 2, 'importance': 0.0},
#   'unwanted': {'count': 2, 'importance': -0.4526}},
#  'cash': {'real': {'count': 4, 'importance': 0.0}},
#  'aspect': {'competitive': {'count': 2, 'importance': -0.2652},
#   'most_important': {'count': 2, 'importance': 0.5432}},
#  'state': {'initial': {'count': 2, 'importance': 0.0}},
#  'features': {'basic': {'count': 2, 'importance': 0.0},
#   'awesome': {'count': 4, 'importance': 2.4996},
#   'little': {'count': 2, 'importance': 0.0},
#   'neat': {'count': 2, 'importance': 0.9176}},
#  'failures': {'worst': {'count': 2, 'importance': -1.2498}},
#  'seasons': {'latest': {'count': 2, 'importance': 0.0},
#   'addition': {'count': 2, 'importance': 0.0}},
#  'chance': {'slightest': {'count': 2, 'importance': 0.0},
#   'actual': {'count': 2, 'importance': 0.0},
#   'worth': {'count': 2, 'importance': 0.4526},
#   'real': {'count': 2, 'importance': 0.0}},
#  'money': {'real': {'count': 30, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'non': {'count': 2, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0},
#   'virtual': {'count': 2, 'importance': 0.0},
#   'actual': {'count': 2, 'importance': 0.0},
#   'especially': {'count': 2, 'importance': 0.0}},
#  'disasters': {'largest': {'count': 2, 'importance': 0.0}},
#  'waste': {'complete': {'count': 2, 'importance': 0.0},
#   'total': {'count': 2, 'importance': 0.0}},
#  'disappointment': {'huge': {'count': 2, 'importance': 0.6364},
#   'hugest': {'count': 2, 'importance': 0.0}},
#  'mechanics': {'wow_like': {'count': 2, 'importance': 1.486},
#   'notch': {'count': 2, 'importance': 0.0}},
#  'system': {'flawed': {'count': 4, 'importance': -1.9068},
#   'new': {'count': 12, 'importance': 0.0},
#   'simplistic': {'count': 2, 'importance': 0.0},
#   'sophisticated': {'count': 2, 'importance': 1.1148},
#   'very_dumbed': {'count': 2, 'importance': -0.801},
#   'crafting': {'count': 2, 'importance': 0.0},
#   '-introduced': {'count': 2, 'importance': 0.0},
#   'updated': {'count': 2, 'importance': 0.0},
#   'weak': {'count': 2, 'importance': -0.8808},
#   'previous': {'count': 2, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0},
#   'joke': {'count': 2, 'importance': 0.592},
#   'lame': {'count': 2, 'importance': -0.843},
#   'simple': {'count': 4, 'importance': 0.0},
#   'streamlined': {'count': 4, 'importance': 0.0},
#   'easy': {'count': 2, 'importance': 0.8808},
#   'online': {'count': 2, 'importance': 0.0},
#   'beefier': {'count': 2, 'importance': 0.0}},
#  'difference': {'huge': {'count': 2, 'importance': 0.6364}},
#  'graphics': {'great': {'count': 4, 'importance': 2.4996},
#   'sharp': {'count': 2, 'importance': 0.0},
#   'good': {'count': 10, 'importance': 4.404},
#   'nonsense': {'count': 2, 'importance': -0.8038},
#   'better': {'count': 10, 'importance': 4.404},
#   'smooth': {'count': 2, 'importance': 0.0},
#   'beautiful': {'count': 2, 'importance': 1.1988},
#   'upgraded': {'count': 2, 'importance': 0.0},
#   'superficial': {'count': 2, 'importance': 0.0},
#   'excellent': {'count': 2, 'importance': 1.1438},
#   'okay': {'count': 2, 'importance': 0.4526},
#   'best': {'count': 2, 'importance': 1.2738},
#   'horrible': {'count': 2, 'importance': -1.0846},
#   'very_polished': {'count': 2, 'importance': 0.0},
#   'nice': {'count': 2, 'importance': 0.843},
#   'simply': {'count': 2, 'importance': 0.0}},
#  'animations': {'nice': {'count': 2, 'importance': 0.843}},
#  'experience': {'online': {'count': 2, 'importance': 0.0},
#   'great': {'count': 6, 'importance': 3.7494000000000005},
#   'fantastic': {'count': 2, 'importance': 1.1148},
#   'single': {'count': 4, 'importance': 0.0},
#   'improved': {'count': 2, 'importance': 0.9534},
#   'good': {'count': 2, 'importance': 0.8808},
#   'completely_enjoyable': {'count': 2, 'importance': 0.9854},
#   'new': {'count': 2, 'importance': 0.0},
#   'overall': {'count': 4, 'importance': 0.0},
#   'deeper': {'count': 2, 'importance': 0.0},
#   'completely_different': {'count': 2, 'importance': 0.0}},
#  'gamer': {'super_avid': {'count': 2, 'importance': 1.4538},
#   'online': {'count': 2, 'importance': 0.0},
#   'hardcore': {'count': 6, 'importance': 0.0},
#   'spoiled': {'count': 2, 'importance': 0.0},
#   'casual': {'count': 2, 'importance': 0.4046},
#   'gamer': {'count': 2, 'importance': 0.0}},
#  'patches': {'new': {'count': 2, 'importance': 0.0},
#   'kind': {'count': 2, 'importance': 1.0534},
#   'amazing': {'count': 2, 'importance': 1.1718}},
#  'rpg': {'online': {'count': 2, 'importance': 0.0},
#   'standard': {'count': 6, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498},
#   'more_traditional': {'count': 2, 'importance': 0.0},
#   'exciting': {'count': 2, 'importance': 0.9878},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'group': {'really_large': {'count': 2, 'importance': 0.0},
#   'closely_knit': {'count': 2, 'importance': 0.0},
#   'large': {'count': 2, 'importance': 0.0},
#   'longer': {'count': 2, 'importance': 0.0}},
#  'storyline': {'good': {'count': 2, 'importance': 0.8808},
#   'interesting': {'count': 2, 'importance': 0.8038}},
#  'games': {'random': {'count': 2, 'importance': 0.0},
#   'excellent': {'count': 2, 'importance': 1.1438},
#   'old': {'count': 4, 'importance': 0.0},
#   'simple': {'count': 2, 'importance': 0.0},
#   'massive': {'count': 2, 'importance': 0.0},
#   'previous': {'count': 28, 'importance': 0.0},
#   'forward': {'count': 2, 'importance': 0.0},
#   'multi': {'count': 4, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0},
#   'earlier': {'count': 6, 'importance': 0.0},
#   'amazing': {'count': 2, 'importance': 1.1718},
#   'usually': {'count': 2, 'importance': 0.0},
#   'masterpieces': {'count': 2, 'importance': 1.0846},
#   'latest': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'new': {'count': 2, 'importance': 0.0},
#   'single': {'count': 2, 'importance': 0.0},
#   'online': {'count': 2, 'importance': 0.0},
#   'boring': {'count': 2, 'importance': 0.4822},
#   'modern': {'count': 2, 'importance': 0.0},
#   'open': {'count': 2, 'importance': 0.0},
#   'actual': {'count': 2, 'importance': 0.0},
#   'favorite': {'count': 4, 'importance': 1.8352},
#   'variable': {'count': 2, 'importance': 0.0},
#   'older': {'count': 2, 'importance': 0.0},
#   'cooperative': {'count': 2, 'importance': 0.0},
#   'best': {'count': 2, 'importance': 1.2738}},
#  'people': {'pretty_cool': {'count': 2, 'importance': 1.341},
#   'odd': {'count': 2, 'importance': -0.6364},
#   'lightly': {'count': 2, 'importance': 0.0},
#   'especially': {'count': 2, 'importance': 0.0},
#   'interested': {'count': 2, 'importance': 0.8038},
#   'hopefully': {'count': 2, 'importance': 0.8038},
#   'random': {'count': 2, 'importance': 0.0},
#   'obviously': {'count': 2, 'importance': 0.0},
#   'distinct': {'count': 2, 'importance': 0.0},
#   'evil': {'count': 2, 'importance': -1.3194},
#   'magic': {'count': 2, 'importance': 0.0},
#   'bored': {'count': 2, 'importance': 0.4114},
#   'online': {'count': 2, 'importance': 0.0}},
#  'diablo': {'previous': {'count': 2, 'importance': 0.0},
#   'games': {'count': 2, 'importance': 0.0},
#   'example': {'count': 2, 'importance': 0.0},
#   'game': {'count': 8, 'importance': 0.0},
#   'best': {'count': 2, 'importance': 1.2738},
#   'overall': {'count': 2, 'importance': 0.0},
#   'so_far': {'count': 2, 'importance': 0.0},
#   'experience': {'count': 2, 'importance': 0.0},
#   'years': {'count': 2, 'importance': 0.0},
#   'not_game': {'count': 2, 'importance': 0.0},
#   'hard_die': {'count': 2, 'importance': -1.2972},
#   'fun': {'count': 4, 'importance': 2.0424},
#   'hyped': {'count': 2, 'importance': 0.0},
#   'awesome': {'count': 2, 'importance': -1.0192},
#   'right': {'count': 2, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498},
#   'traditional': {'count': 2, 'importance': 0.0},
#   'alway': {'count': 2, 'importance': 0.0},
#   'completely': {'count': 2, 'importance': 0.0}},
#  'par': {'sub': {'count': 2, 'importance': 0.0}},
#  'nothing': {'new': {'count': 6, 'importance': 0.0},
#   'exceptional': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'second': {'actually': {'count': 2, 'importance': 0.0}},
#  'fan': {'big': {'count': 10, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498},
#   'huge': {'count': 6, 'importance': 1.9092},
#   'diehard': {'count': 2, 'importance': 0.0}},
#  'thing': {'online': {'count': 2, 'importance': 0.0},
#   'sucky': {'count': 2, 'importance': -0.8808},
#   'biggest': {'count': 2, 'importance': 0.0},
#   'scenes': {'count': 2, 'importance': 0.0},
#   'stupid': {'count': 2, 'importance': -1.0534},
#   'frustrating': {'count': 2, 'importance': -0.8808},
#   'bad': {'count': 6, 'importance': -3.2538},
#   'old': {'count': 2, 'importance': 0.0},
#   'most_important': {'count': 2, 'importance': 0.5432},
#   'room': {'count': 2, 'importance': 0.0},
#   'hindrance': {'count': 2, 'importance': -0.8038},
#   'good': {'count': 6, 'importance': 2.6424},
#   'basically': {'count': 2, 'importance': 0.0},
#   'exact': {'count': 4, 'importance': 0.0},
#   'right': {'count': 2, 'importance': 0.0},
#   'shiny': {'count': 2, 'importance': 0.0},
#   'negative': {'count': 2, 'importance': -1.1438},
#   'achievements': {'count': 2, 'importance': 0.0}},
#  'enemies': {'later': {'count': 2, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0},
#   'new': {'count': 2, 'importance': 0.0},
#   'slain': {'count': 2, 'importance': 0.0},
#   'ever_increasing': {'count': 2, 'importance': 0.0}},
#  'meters': {'specific': {'count': 2, 'importance': 0.0}},
#  'match': {'better': {'count': 2, 'importance': 0.8808}},
#  'amount': {'large': {'count': 2, 'importance': 0.0},
#   'endless': {'count': 2, 'importance': 0.0},
#   'exorbitant': {'count': 2, 'importance': 0.0},
#   'embarrassingly_high': {'count': 2, 'importance': -0.8038}},
#  'successor': {'worthy': {'count': 4, 'importance': 1.7616},
#   'great': {'count': 2, 'importance': 1.2498}},
#  'factor': {'fun': {'count': 4, 'importance': 2.0424},
#   'so_far': {'count': 2, 'importance': 0.0},
#   'automatically': {'count': 2, 'importance': 0.0}},
#  'dungeon': {'new': {'count': 2, 'importance': 0.0},
#   'optional': {'count': 2, 'importance': 0.0}},
#  'memories': {'fond': {'count': 2, 'importance': 0.8808}},
#  'swords': {'filled': {'count': 2, 'importance': 0.0}},
#  'expansion': {'eventual': {'count': 2, 'importance': 0.0},
#   'hopefully': {'count': 2, 'importance': 0.8038},
#   'new': {'count': 2, 'importance': 0.0},
#   'newest': {'count': 2, 'importance': 0.0}},
#  'characters': {'additional': {'count': 2, 'importance': 0.0},
#   'ranged': {'count': 2, 'importance': 0.0},
#   'different': {'count': 4, 'importance': 0.0},
#   'best': {'count': 2, 'importance': 1.2738},
#   'hardcore': {'count': 2, 'importance': 0.0},
#   'interactive': {'count': 2, 'importance': 0.0},
#   'new': {'count': 2, 'importance': 0.0},
#   'multiple': {'count': 2, 'importance': 0.0},
#   'more_accomplished': {'count': 2, 'importance': 0.9854}},
#  'let': {'little': {'count': 2, 'importance': 0.0},
#   'huge': {'count': 2, 'importance': 0.6364}},
#  'access': {'best': {'count': 2, 'importance': 1.2738}},
#  'ways': {'better': {'count': 2, 'importance': 0.8808},
#   'que': {'count': 2, 'importance': 0.0}},
#  'butt': {'lazy': {'count': 2, 'importance': -0.7224}},
#  '3': {'comment': {'count': 2, 'importance': 0.0}},
#  'patch': {'new': {'count': 4, 'importance': 0.0},
#   'massive': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'most_recent': {'count': 2, 'importance': 0.0},
#   'future': {'count': 2, 'importance': 0.0}},
#  'in': {'general': {'count': 2, 'importance': 0.0},
#   'short': {'count': 2, 'importance': 0.0},
#   'active': {'count': 2, 'importance': 0.8038},
#   'particular': {'count': 4, 'importance': 0.0}},
#  'comments': {'visible': {'count': 2, 'importance': 0.0},
#   'horrible': {'count': 2, 'importance': -1.0846},
#   'crappy': {'count': 2, 'importance': -1.1148}},
#  'op': {'way': {'count': 2, 'importance': 0.0}},
#  'ally': {'summoned': {'count': 2, 'importance': 0.0}},
#  'spells': {'pretty_cool': {'count': 2, 'importance': 1.341},
#   'stranger': {'count': 2, 'importance': 0.0},
#   'direct': {'count': 2, 'importance': 0.0},
#   'offensive': {'count': 2, 'importance': -0.9176}},
#  'cooldown': {'long': {'count': 2, 'importance': 0.0}},
#  'ability': {'leaping': {'count': 2, 'importance': 0.0}},
#  'annoyances': {'still_fun': {'count': 2, 'importance': 1.0212},
#   'minor': {'count': 2, 'importance': 0.0}},
#  'grade': {'passing': {'count': 2, 'importance': 0.0}},
#  'style': {'colorful': {'count': 2, 'importance': 0.0},
#   'cool': {'count': 2, 'importance': 0.6364},
#   'simple': {'count': 2, 'importance': 0.0},
#   'little': {'count': 2, 'importance': 0.0},
#   'newer': {'count': 2, 'importance': 0.0}},
#  'music': {'forgettable': {'count': 2, 'importance': 0.0},
#   'modern': {'count': 2, 'importance': 0.0}},
#  'audience': {'younger': {'count': 2, 'importance': 0.0}},
#  'mature': {'greatly': {'count': 2, 'importance': 0.0}},
#  'player': {'single': {'count': 64, 'importance': 0.0},
#   'brief': {'count': 2, 'importance': 0.0},
#   'casual': {'count': 4, 'importance': 0.8092},
#   'short': {'count': 2, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': -0.8046},
#   'old': {'count': 2, 'importance': 0.0},
#   'actually': {'count': 2, 'importance': 0.0},
#   'new': {'count': 2, 'importance': 0.0},
#   'typical': {'count': 2, 'importance': 0.0},
#   "n't_player": {'count': 2, 'importance': 0.0},
#   'normal': {'count': 2, 'importance': 0.0},
#   'leeching': {'count': 2, 'importance': 0.0}},
#  'release': {'terrible': {'count': 2, 'importance': -0.9534},
#   'major': {'count': 2, 'importance': 0.0}},
#  'interruption': {'continued': {'count': 2, 'importance': 0.0}},
#  'play': {'oversimplified': {'count': 2, 'importance': 0.0},
#   'online': {'count': 8, 'importance': 0.0},
#   'exciting': {'count': 2, 'importance': 0.9878},
#   'better': {'count': 2, 'importance': 0.8808},
#   'offline': {'count': 4, 'importance': -0.512},
#   'single': {'count': 2, 'importance': 0.0},
#   'worse': {'count': 2, 'importance': -0.9534},
#   'good': {'count': 4, 'importance': 1.7616},
#   'dull': {'count': 2, 'importance': -0.8038},
#   'stars': {'count': 2, 'importance': 0.0},
#   'annoying': {'count': 2, 'importance': -0.8038}},
#  'packaging': {'fine': {'count': 2, 'importance': 0.4046}},
#  'friend': {'unemployed': {'count': 2, 'importance': 0.0}},
#  'fewer': {'excellently': {'count': 2, 'importance': 1.2498}},
#  'drm': {'draconian': {'count': 2, 'importance': 0.0},
#   'always_online': {'count': 2, 'importance': 0.0},
#   'online': {'count': 4, 'importance': 0.0},
#   'damnable': {'count': 2, 'importance': -0.8038}},
#  'product': {'defective': {'count': 4, 'importance': -1.7616},
#   'excellent': {'count': 4, 'importance': 2.2876},
#   'great': {'count': 2, 'importance': 1.2498},
#   'better': {'count': 2, 'importance': 0.8808}},
#  'pirates': {'offline': {'count': 2, 'importance': -0.256}},
#  '\n\n': {'offline': {'count': 2, 'importance': -0.256},
#   'bad': {'count': 2, 'importance': -1.0846},
#   'addictive': {'count': 2, 'importance': 0.0},
#   'maybe': {'count': 2, 'importance': 0.0}},
#  'isp': {'unreliable': {'count': 2, 'importance': 0.0},
#   '\n\n': {'count': 2, 'importance': 0.0}},
#  'idea': {'dumbest': {'count': 2, 'importance': -1.0212},
#   'bad': {'count': 4, 'importance': -2.1692},
#   'fun': {'count': 2, 'importance': 1.0212},
#   'really_bad': {'count': 2, 'importance': -1.1698}},
#  'fight': {'major': {'count': 2, 'importance': 0.0}},
#  'angle': {'far_away': {'count': 2, 'importance': 0.0},
#   'demonic': {'count': 2, 'importance': 0.0},
#   "n't_style": {'count': 2, 'importance': 0.0}},
#  'character': {'premade': {'count': 2, 'importance': 0.0},
#   'doctor': {'count': 2, 'importance': 0.0},
#   'favorite': {'count': 2, 'importance': 0.9176},
#   'so_far': {'count': 2, 'importance': 0.0},
#   'hunter': {'count': 2, 'importance': 0.0},
#   'new': {'count': 4, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0},
#   'linear': {'count': 4, 'importance': 0.0},
#   'unique': {'count': 2, 'importance': 0.0},
#   'main': {'count': 2, 'importance': 0.0},
#   'ready': {'count': 2, 'importance': -0.551},
#   '2nd': {'count': 2, 'importance': 0.0},
#   'particular': {'count': 2, 'importance': 0.0},
#   'best': {'count': 2, 'importance': 1.2738},
#   'buffed': {'count': 2, 'importance': 0.0},
#   'godlike': {'count': 2, 'importance': 0.0}},
#  'option': {'male': {'count': 2, 'importance': 0.0},
#   'single': {'count': 4, 'importance': 0.0},
#   'manageable': {'count': 2, 'importance': 0.0}},
#  'hair': {'facial': {'count': 2, 'importance': 0.0}},
#  'armor': {'matched': {'count': 2, 'importance': 0.0},
#   'certain': {'count': 2, 'importance': 0.5464}},
#  'set': {'entire': {'count': 2, 'importance': 0.0}},
#  'scenes': {'cut': {'count': 4, 'importance': -1.0928},
#   'enjoyable': {'count': 2, 'importance': 0.8808},
#   'away': {'count': 2, 'importance': 0.0},
#   'intense': {'count': 2, 'importance': 0.1544}},
#  'animation': {'mind': {'count': 2, 'importance': 0.0}},
#  'installment': {'previous': {'count': 2, 'importance': 0.0}},
#  'downfall': {'major': {'count': 2, 'importance': 0.0}},
#  'hunter': {'barbarian': {'count': 2, 'importance': 0.0}},
#  'attributes': {'automatically': {'count': 2, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0}},
#  'rates': {'better': {'count': 2, 'importance': 0.8808},
#   'similar': {'count': 2, 'importance': 0.0},
#   'how_high': {'count': 2, 'importance': 0.0},
#   'melee': {'count': 2, 'importance': 0.0}},
#  'difficulty': {'manageable': {'count': 2, 'importance': 0.0},
#   'normal': {'count': 4, 'importance': 0.0},
#   'higher': {'count': 4, 'importance': 0.0},
#   'ultra': {'count': 2, 'importance': 0.0},
#   'punishing': {'count': 2, 'importance': -1.1148},
#   'inferno': {'count': 2, 'importance': 0.0},
#   'overall': {'count': 2, 'importance': 0.0},
#   'highest': {'count': 2, 'importance': 0.0},
#   'latter_hardest': {'count': 2, 'importance': 0.0},
#   'harder': {'count': 2, 'importance': 0.0},
#   'hardest': {'count': 2, 'importance': 0.0}},
#  'multiplayer': {'fun': {'count': 2, 'importance': -0.8046},
#   'alright': {'count': 2, 'importance': 0.5},
#   'boring': {'count': 2, 'importance': -0.6364}},
#  'rmah': {'idea': {'count': 2, 'importance': 0.0}},
#  'options': {'different': {'count': 4, 'importance': 0.0},
#   'mixed': {'count': 2, 'importance': 0.0}},
#  'detriments': {'greatest': {'count': 2, 'importance': 1.2738}},
#  'hours': {'countless': {'count': 4, 'importance': 0.0}},
#  'value': {'wonderful': {'count': 2, 'importance': 1.1438},
#   'ok': {'count': 2, 'importance': 0.592},
#   'aesthetic': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'costs': {'additional': {'count': 2, 'importance': 0.0},
#   'high': {'count': 2, 'importance': 0.0}},
#  'gaming': {'online': {'count': 2, 'importance': 0.0}},
#  'better': {'original': {'count': 2, 'importance': 0.6364}},
#  'reviews': {'negative': {'count': 14, 'importance': -8.0066},
#   'original': {'count': 2, 'importance': 0.6364},
#   'bad': {'count': 4, 'importance': -2.1692},
#   'unwarranted': {'count': 2, 'importance': 0.0},
#   'positive': {'count': 2, 'importance': 1.1148},
#   'better': {'count': 2, 'importance': 0.8808},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'issue': {'bigger': {'count': 2, 'importance': 0.0},
#   'fact': {'count': 2, 'importance': 0.0},
#   'biggest': {'count': 2, 'importance': 0.0},
#   'based': {'count': 2, 'importance': 0.0},
#   'very_big': {'count': 2, 'importance': 0.0}},
#  'fact': {'simple': {'count': 2, 'importance': 0.0}},
#  'eula': {'new': {'count': 2, 'importance': 0.0}},
#  'dollars': {'hard_earned': {'count': 2, 'importance': -0.2054},
#   'big': {'count': 2, 'importance': 0.0}},
#  'model': {'failed': {'count': 2, 'importance': -1.0212},
#   'newer': {'count': 2, 'importance': 0.0}},
#  'company': {'loser': {'count': 2, 'importance': -1.0534},
#   'once_great': {'count': 2, 'importance': 1.2498},
#   'good': {'count': 2, 'importance': 0.8808},
#   'successful': {'count': 2, 'importance': 1.1718},
#   'focused': {'count': 2, 'importance': 0.7636},
#   'excellent': {'count': 2, 'importance': 1.1438},
#   'new': {'count': 2, 'importance': 0.0}},
#  'story': {'simple': {'count': 2, 'importance': 0.0},
#   'good': {'count': 4, 'importance': 0.19840000000000008},
#   'rpg': {'count': 2, 'importance': 0.0},
#   'illogical': {'count': 2, 'importance': 0.0},
#   'pretty_good': {'count': 2, 'importance': 1.4538},
#   'more_thrilling': {'count': 2, 'importance': 1.0512},
#   'exact': {'count': 2, 'importance': 0.0},
#   'much_larger': {'count': 2, 'importance': 0.0},
#   'excellent': {'count': 2, 'importance': 1.1438},
#   'boring': {'count': 4, 'importance': -1.2728},
#   'greatest': {'count': 2, 'importance': 1.2738},
#   'horrible': {'count': 2, 'importance': -1.0846},
#   'poor': {'count': 2, 'importance': -0.9534},
#   'decent': {'count': 2, 'importance': 0.0},
#   'basically': {'count': 2, 'importance': 0.0}},
#  'trail': {'free': {'count': 2, 'importance': 1.0212}},
#  'edition': {'starter': {'count': 8, 'importance': 0.0},
#   'free': {'count': 2, 'importance': 1.0212}},
#  'amazement': {'utter': {'count': 2, 'importance': 0.0}},
#  'demonic': {'hellish': {'count': 2, 'importance': -1.2738}},
#  'fun': {'utter': {'count': 2, 'importance': 0.0},
#   'great': {'count': 8, 'importance': 4.999200000000001},
#   'classic': {'count': 2, 'importance': 0.0},
#   'pounding': {'count': 2, 'importance': 0.0},
#   'away': {'count': 2, 'importance': 0.0},
#   'more_pure': {'count': 2, 'importance': 0.0},
#   'addictively': {'count': 2, 'importance': 0.0},
#   'mindless': {'count': 2, 'importance': -0.8808},
#   'best': {'count': 2, 'importance': 1.2738},
#   'decent': {'count': 2, 'importance': 0.0}},
#  'mess': {'red': {'count': 2, 'importance': 0.0},
#   'gooey': {'count': 2, 'importance': 0.0},
#   'initial': {'count': 2, 'importance': 0.0},
#   'broken': {'count': 2, 'importance': -0.9534}},
#  'loot': {'shiny': {'count': 2, 'importance': 0.0},
#   'new': {'count': 4, 'importance': 0.0},
#   'better': {'count': 6, 'importance': 2.6424},
#   'rare': {'count': 6, 'importance': 0.0},
#   'cool': {'count': 2, 'importance': 0.6364},
#   'vastly': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'terrible': {'count': 2, 'importance': -0.9534},
#   'common': {'count': 2, 'importance': 0.0},
#   'special': {'count': 2, 'importance': 0.8038}},
#  'settings': {'maximum': {'count': 2, 'importance': 0.0},
#   'beautiful': {'count': 2, 'importance': 1.1988},
#   'progressively_harder': {'count': 2, 'importance': 0.0},
#   'lowest': {'count': 2, 'importance': -0.7636},
#   'graphic': {'count': 2, 'importance': 0.0}},
#  'world': {'detailed': {'count': 2, 'importance': 0.0},
#   'alive': {'count': 2, 'importance': 0.7636},
#   'open': {'count': 4, 'importance': 0.0}},
#  'day': {'single': {'count': 2, 'importance': 0.0},
#   'otherwise_bad': {'count': 2, 'importance': -1.0846}},
#  'acts': {'entertaining': {'count': 2, 'importance': 0.8808},
#   'more_advanced': {'count': 2, 'importance': 0.6334}},
#  'battles': {'enjoyable': {'count': 2, 'importance': 0.8808},
#   'actual': {'count': 2, 'importance': 0.0}},
#  'banter': {'constant': {'count': 2, 'importance': 0.0}},
#  'profession': {'virtual': {'count': 2, 'importance': 0.0}},
#  'chore': {'repetitive': {'count': 2, 'importance': -0.5}},
#  'level': {'normal': {'count': 2, 'importance': 0.0},
#   'expert': {'count': 2, 'importance': 0.0},
#   '60': {'count': 2, 'importance': 0.0},
#   'current': {'count': 2, 'importance': 0.0},
#   'new': {'count': 2, 'importance': 0.0},
#   'non': {'count': 2, 'importance': 0.0},
#   'magical': {'count': 4, 'importance': 0.0},
#   'rare': {'count': 2, 'importance': 0.0},
#   'legendary': {'count': 2, 'importance': 0.0},
#   'pony': {'count': 2, 'importance': 0.0},
#   'high': {'count': 4, 'importance': 0.0},
#   'entirely_new': {'count': 2, 'importance': 0.0},
#   'low': {'count': 4, 'importance': -1.0928},
#   'lower': {'count': 4, 'importance': -1.184},
#   'lowest': {'count': 2, 'importance': -0.7636},
#   'prior': {'count': 2, 'importance': 0.0},
#   'barbarian': {'count': 2, 'importance': 0.0},
#   'previously': {'count': 2, 'importance': 0.0},
#   'final': {'count': 2, 'importance': 0.0},
#   'difficult': {'count': 2, 'importance': -0.7224}},
#  'monies': {'worth': {'count': 2, 'importance': 0.4526}},
#  'aspects': {'really_involved': {'count': 2, 'importance': 0.0},
#   'unpolished': {'count': 2, 'importance': 0.0},
#   'ongoing': {'count': 2, 'importance': 0.0},
#   'so_controlled': {'count': 2, 'importance': 0.0},
#   'evident': {'count': 2, 'importance': 0.0},
#   'frustrating': {'count': 2, 'importance': -0.8808},
#   'best': {'count': 2, 'importance': 1.2738}},
#  'battlegrounds': {'based': {'count': 2, 'importance': 0.0}},
#  'weapons': {'best': {'count': 2, 'importance': 1.2738},
#   'good': {'count': 4, 'importance': 1.7616},
#   'new': {'count': 2, 'importance': 0.0},
#   'chosen': {'count': 2, 'importance': 0.0},
#   'melee': {'count': 4, 'importance': 0.0}},
#  'news': {'great': {'count': 2, 'importance': 1.2498},
#   'bad': {'count': 2, 'importance': -1.0846},
#   'limited': {'count': 2, 'importance': -0.4526},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'time': {'second': {'count': 6, 'importance': 0.0},
#   'given': {'count': 4, 'importance': 0.0},
#   'long': {'count': 12, 'importance': 0.0},
#   'amazing': {'count': 2, 'importance': 1.1718},
#   'epic': {'count': 2, 'importance': 0.0},
#   'wonderful': {'count': 2, 'importance': 1.1438},
#   'perfect': {'count': 2, 'importance': 1.1438},
#   'free': {'count': 4, 'importance': 2.0424},
#   'available': {'count': 2, 'importance': 0.0},
#   'extra': {'count': 2, 'importance': 0.0},
#   'little': {'count': 2, 'importance': 0.0},
#   'fourth': {'count': 2, 'importance': 0.0},
#   'entire': {'count': 2, 'importance': 0.0},
#   'big': {'count': 2, 'importance': 0.0},
#   'multiple': {'count': 2, 'importance': 0.0},
#   'harder': {'count': 2, 'importance': 0.0},
#   'total': {'count': 2, 'importance': 0.0},
#   'spare': {'count': 2, 'importance': 0.0},
#   'real': {'count': 2, 'importance': 0.0},
#   'eastern': {'count': 2, 'importance': 0.0}},
#  'bosses': {'joke': {'count': 2, 'importance': 0.592}},
#  'redundancy': {'simple': {'count': 2, 'importance': 0.0}},
#  'lore': {'rich': {'count': 2, 'importance': 1.1148}},
#  'beef': {'major': {'count': 2, 'importance': 0.0},
#   'slight': {'count': 2, 'importance': 0.0}},
#  'classes': {'best': {'count': 2, 'importance': 1.2738},
#   'entire': {'count': 2, 'importance': 0.0},
#   'doctor': {'count': 2, 'importance': 0.0},
#   'very_laggy': {'count': 2, 'importance': 0.0},
#   'wide': {'count': 2, 'importance': 0.0},
#   'different': {'count': 6, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': 1.0212},
#   'open': {'count': 2, 'importance': 0.0},
#   'multiple': {'count': 4, 'importance': 0.0},
#   'certain': {'count': 2, 'importance': 0.5464},
#   'easier': {'count': 2, 'importance': 0.843},
#   'basically': {'count': 2, 'importance': 0.0}},
#  'alternative': {'viable': {'count': 2, 'importance': 0.0}},
#  'wait': {'long': {'count': 2, 'importance': 0.0},
#   'worth': {'count': 2, 'importance': 0.4526}},
#  'class': {'best': {'count': 2, 'importance': 1.2738},
#   'necromancer': {'count': 2, 'importance': 0.0},
#   'barbarian': {'count': 2, 'importance': 0.0},
#   'different': {'count': 4, 'importance': 0.0},
#   'current': {'count': 2, 'importance': 0.0}},
#  'part': {'worst': {'count': 2, 'importance': -1.2498},
#   'second': {'count': 2, 'importance': 0.0},
#   'big': {'count': 4, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'most_addicting': {'count': 2, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498},
#   'bad': {'count': 2, 'importance': -1.0846}},
#  'mode': {'more_difficult': {'count': 2, 'importance': -0.8402},
#   'single': {'count': 4, 'importance': 0.0},
#   'offline': {'count': 8, 'importance': -0.13159999999999994},
#   'normal': {'count': 12, 'importance': 0.0},
#   'online': {'count': 2, 'importance': 0.0},
#   'difficult': {'count': 2, 'importance': -0.7224}},
#  'something': {'mindless': {'count': 2, 'importance': -0.8808},
#   'new': {'count': 2, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498},
#   'similar': {'count': 2, 'importance': 0.0}},
#  'bucks': {'waste': {'count': 2, 'importance': -0.843}},
#  'levels': {'higher': {'count': 8, 'importance': 0.0},
#   'numerous': {'count': 2, 'importance': 0.0},
#   'almost_exactly': {'count': 2, 'importance': 0.0},
#   'single': {'count': 2, 'importance': 0.0},
#   'early': {'count': 2, 'importance': 0.0},
#   'duplicates': {'count': 2, 'importance': 0.0},
#   'second': {'count': 2, 'importance': 0.0}},
#  'old': {'old': {'count': 2, 'importance': 0.0},
#   'awesome': {'count': 2, 'importance': 1.2498}},
#  'maps': {'randomly_generated': {'count': 2, 'importance': 0.0},
#   'huge': {'count': 2, 'importance': 0.6364},
#   'random': {'count': 2, 'importance': 0.0}},
#  'core': {'hard': {'count': 4, 'importance': -0.4108}},
#  'd2': {'forever': {'count': 2, 'importance': 0.0},
#   'foray': {'count': 2, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': 1.0212},
#   'perfect': {'count': 2, 'importance': 1.1438},
#   'old': {'count': 2, 'importance': 0.0},
#   'better': {'count': 2, 'importance': 0.8808}},
#  'coin': {'dropped': {'count': 2, 'importance': 0.0}},
#  'flaw': {'big': {'count': 2, 'importance': 0.0}},
#  'quota': {'fun': {'count': 2, 'importance': 1.0212}},
#  'reasoning': {'too_far': {'count': 2, 'importance': 0.0}},
#  'record': {'good': {'count': 2, 'importance': 0.8808}},
#  'management': {'new': {'count': 2, 'importance': 0.0},
#   'bad': {'count': 2, 'importance': -1.0846}},
#  'purpose': {'special': {'count': 2, 'importance': 0.8038},
#   'real': {'count': 2, 'importance': 0.0}},
#  'trend': {'sale': {'count': 2, 'importance': 0.0},
#   'sadly': {'count': 2, 'importance': -0.843}},
#  'number': {'limited': {'count': 2, 'importance': -0.4526},
#   'ridiculous': {'count': 2, 'importance': -0.7224},
#   'small': {'count': 2, 'importance': 0.0},
#   'finite': {'count': 2, 'importance': 0.0},
#   'large': {'count': 2, 'importance': 0.0},
#   'huge': {'count': 2, 'importance': 0.6364}},
#  'buddies': {'multi': {'count': 2, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0},
#   'player': {'count': 2, 'importance': 0.0}},
#  'advantage': {'clear': {'count': 2, 'importance': 0.7636}},
#  'look': {'hard': {'count': 2, 'importance': -0.2054},
#   'closer': {'count': 2, 'importance': 0.0},
#   'cartoonish': {'count': 2, 'importance': 0.0}},
#  'playing': {'online': {'count': 2, 'importance': 0.0}},
#  'companion': {'multi': {'count': 2, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0},
#   'player': {'count': 2, 'importance': 0.0}},
#  'blip': {'occassional': {'count': 2, 'importance': 0.0}},
#  'video': {'choppy': {'count': 2, 'importance': 0.0}},
#  'reason': {'best': {'count': 2, 'importance': 1.2738},
#   'little': {'count': 2, 'importance': 0.0},
#   'real': {'count': 2, 'importance': 0.0}},
#  'everything': {'slightly_wrong': {'count': 2, 'importance': -0.8456}},
#  'school': {'old': {'count': 2, 'importance': 0.0}},
#  'tree': {'stupid': {'count': 2, 'importance': -1.0534},
#   'big': {'count': 2, 'importance': 0.0},
#   'complex': {'count': 2, 'importance': 0.0},
#   'longer': {'count': 2, 'importance': 0.0}},
#  'disconnects': {'annoying': {'count': 2, 'importance': -0.8038},
#   'probably': {'count': 2, 'importance': 0.0}},
#  'update': {'excellent': {'count': 2, 'importance': 1.1438},
#   'real': {'count': 2, 'importance': 0.0},
#   'preceding': {'count': 2, 'importance': 0.0}},
#  'patched': {'new': {'count': 2, 'importance': 0.0}},
#  'blizzard': {'legendary': {'count': 2, 'importance': 0.0},
#   'nice': {'count': 2, 'importance': 0.843},
#   'considerably': {'count': 2, 'importance': 0.0},
#   'simply': {'count': 4, 'importance': 0.0},
#   'certainly': {'count': 2, 'importance': 0.68},
#   'stupid': {'count': 2, 'importance': 0.8336},
#   'constantly': {'count': 2, 'importance': 0.0},
#   'clear': {'count': 2, 'importance': 0.7636},
#   'prepared': {'count': 2, 'importance': -0.339},
#   'clearly': {'count': 2, 'importance': -0.6178},
#   'dead': {'count': 2, 'importance': -1.2972},
#   'dramatically': {'count': 2, 'importance': 0.0},
#   'completely_shocked': {'count': 2, 'importance': -0.7608},
#   'lately': {'count': 2, 'importance': 0.0},
#   'interested': {'count': 2, 'importance': 0.8038}},
#  'plan': {'purely_idiotic': {'count': 2, 'importance': -1.1968},
#   'evil': {'count': 2, 'importance': -1.3194}},
#  'price': {'great': {'count': 4, 'importance': 2.4996},
#   'current': {'count': 2, 'importance': 0.0},
#   'pre': {'count': 2, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0},
#   'order': {'count': 2, 'importance': 0.0},
#   'cheap': {'count': 2, 'importance': 0.0},
#   'good': {'count': 4, 'importance': 1.7616},
#   'high': {'count': 2, 'importance': 0.0}},
#  'curve': {'steep': {'count': 2, 'importance': 0.0},
#   'very_fast': {'count': 2, 'importance': 0.0}},
#  'versions': {'previous': {'count': 8, 'importance': 0.0},
#   'older': {'count': 2, 'importance': 0.0},
#   'prior': {'count': 4, 'importance': 0.0},
#   'okay': {'count': 2, 'importance': 0.4526}},
#  'version': {'newer': {'count': 2, 'importance': 0.0},
#   'new': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'prettier': {'count': 2, 'importance': 0.9534},
#   'actual': {'count': 2, 'importance': 0.0},
#   'boxed': {'count': 2, 'importance': 0.0},
#   'previous': {'count': 2, 'importance': 0.0},
#   'updated': {'count': 2, 'importance': 0.0}},
#  'ones': {'older': {'count': 2, 'importance': 0.0},
#   'monk': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'gold': {'count': 2, 'importance': 0.0},
#   'green': {'count': 2, 'importance': 0.0},
#   'best': {'count': 2, 'importance': 1.2738},
#   'previous': {'count': 4, 'importance': 0.0},
#   'useful': {'count': 2, 'importance': 0.8808}},
#  'trip': {'totally_linear': {'count': 2, 'importance': 0.0},
#   '5th': {'count': 2, 'importance': 0.0}},
#  'trips': {'occasional': {'count': 2, 'importance': 0.0}},
#  'that': {'normal': {'count': 2, 'importance': 0.0}},
#  'complaint': {'biggest': {'count': 2, 'importance': 0.0},
#   'fact': {'count': 2, 'importance': 0.0},
#   'major': {'count': 2, 'importance': 0.0}},
#  'attacks': {'main': {'count': 2, 'importance': 0.0},
#   'single': {'count': 2, 'importance': 0.0},
#   'insane': {'count': 2, 'importance': -0.8038},
#   'ranged': {'count': 2, 'importance': 0.0}},
#  'plus': {'huge': {'count': 2, 'importance': 0.6364}},
#  'assortment': {'strange': {'count': 2, 'importance': -0.4046}},
#  'ah': {'soon': {'count': 2, 'importance': 0.0}},
#  'copy': {'working': {'count': 2, 'importance': 0.0},
#   'second': {'count': 2, 'importance': 0.0},
#   'physical': {'count': 2, 'importance': 0.0}},
#  'surprises': {'more_cool': {'count': 2, 'importance': 0.7608}},
#  'teacher': {'english': {'count': 2, 'importance': 0.0}},
#  'power': {'evil': {'count': 2, 'importance': -1.3194},
#   'particular': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808}},
#  'addition': {'nice': {'count': 4, 'importance': 1.686},
#   'house': {'count': 2, 'importance': 0.0},
#   'wonderful': {'count': 2, 'importance': 1.1438},
#   'fun': {'count': 2, 'importance': 1.0212}},
#  'crafting': {'addition': {'count': 2, 'importance': 0.0}},
#  'choices': {'very_unique': {'count': 2, 'importance': 0.0},
#   'permanent': {'count': 2, 'importance': 0.0},
#   'myriad': {'count': 2, 'importance': 0.0}},
#  'amounts': {'huge': {'count': 2, 'importance': 0.6364},
#   'increasing': {'count': 2, 'importance': 0.0}},
#  'pursuit': {'endless': {'count': 2, 'importance': 0.0}},
#  'method': {'impersonal': {'count': 2, 'importance': -0.6364}},
#  'join': {'random': {'count': 2, 'importance': 0.0}},
#  'itemization': {'slow': {'count': 2, 'importance': 0.0},
#   '+25': {'count': 2, 'importance': 0.0},
#   'poor': {'count': 2, 'importance': -0.9534}},
#  'work': {'major': {'count': 2, 'importance': 0.0},
#   'too_old': {'count': 2, 'importance': 0.0},
#   'hard': {'count': 4, 'importance': -0.4108},
#   'quality': {'count': 2, 'importance': 0.0}},
#  'change': {'big': {'count': 2, 'importance': 0.0},
#   'biggest': {'count': 2, 'importance': 0.0},
#   'particular': {'count': 2, 'importance': 0.0},
#   'profoundly': {'count': 2, 'importance': 0.0}},
#  'numbers': {'large': {'count': 2, 'importance': 0.0},
#   'higher': {'count': 2, 'importance': 0.0}},
#  'way': {'different': {'count': 2, 'importance': 0.0},
#   'easy': {'count': 2, 'importance': -0.6824},
#   'legal': {'count': 2, 'importance': -0.1902},
#   'nicer': {'count': 2, 'importance': 0.8808},
#   'very_long': {'count': 2, 'importance': 0.0},
#   'far_greater': {'count': 2, 'importance': 0.7224},
#   'improved': {'count': 2, 'importance': 0.9534},
#   'best': {'count': 2, 'importance': 1.2738},
#   'wrong': {'count': 2, 'importance': -0.9534},
#   'possible': {'count': 2, 'importance': 0.0},
#   'long': {'count': 2, 'importance': 0.0}},
#  'those': {'unfamiliar': {'count': 2, 'importance': 0.0}},
#  'place': {'as_good': {'count': 2, 'importance': 0.8808},
#   'new': {'count': 2, 'importance': 0.0}},
#  'skills': {'new': {'count': 4, 'importance': 0.0},
#   'limited': {'count': 2, 'importance': -0.4526},
#   'passive': {'count': 2, 'importance': 0.4046},
#   'predefined': {'count': 2, 'importance': 0.0},
#   'special': {'count': 2, 'importance': 0.8038},
#   'chosen': {'count': 2, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': 1.0212},
#   'different': {'count': 4, 'importance': 0.0},
#   'really_good': {'count': 2, 'importance': 0.9854},
#   'better': {'count': 4, 'importance': 1.7616},
#   'worthwhile': {'count': 2, 'importance': 0.68}},
#  'rating': {'mature': {'count': 2, 'importance': 0.843},
#   'overall': {'count': 2, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': 1.0212},
#   'tricky': {'count': 2, 'importance': -0.3062},
#   'actually': {'count': 2, 'importance': 0.0},
#   'stars': {'count': 2, 'importance': 0.0}},
#  'violence': {'glorious': {'count': 2, 'importance': 1.2738},
#   'gratuitious': {'count': 2, 'importance': 0.0}},
#  'installments': {'previous': {'count': 4, 'importance': 0.0}},
#  'size': {'4': {'count': 2, 'importance': 0.0}},
#  'customization': {'already_limited': {'count': 2, 'importance': -0.4526},
#   'limited': {'count': 2, 'importance': -0.4526},
#   'usually': {'count': 2, 'importance': 0.0}},
#  'variations': {'minor': {'count': 2, 'importance': 0.0}},
#  'doctor': {'just_hi': {'count': 2, 'importance': 0.0}},
#  '1/3': {'useful': {'count': 2, 'importance': 0.8808}},
#  'sorc': {'-': {'count': 2, 'importance': 0.0},
#   'rolled': {'count': 2, 'importance': 0.0}},
#  'prices': {'insane': {'count': 2, 'importance': -0.8038},
# ...
#   'limited': {'count': 2, 'importance': -0.4526}},
#  'effects': {'special': {'count': 2, 'importance': 0.8038},
#   'familiar': {'count': 2, 'importance': 0.0}},
#  'rise': {'high': {'count': 2, 'importance': 0.0}},
#  'bridge': {'cathedral': {'count': 2, 'importance': 0.0}},
#  'replay': {'very_low': {'count': 2, 'importance': -0.6768}},
#  'mobs': {'average': {'count': 2, 'importance': 0.0},
#   'pools': {'count': 2, 'importance': 0.0},
#   'bit': {'count': 2, 'importance': 0.0}},
#  'cartoon': {'active': {'count': 2, 'importance': 0.8038}},
#  'chars': {'ok': {'count': 2, 'importance': 0.592}},
#  'combo': {'winning': {'count': 2, 'importance': 1.0534}},
#  'scouting': {'little': {'count': 2, 'importance': 0.0}},
#  'goods': {'bought': {'count': 2, 'importance': 0.0}},
#  'chandelier': {'falling': {'count': 2, 'importance': -0.3062}},
#  'walls': {'weak': {'count': 2, 'importance': -0.8808}},
#  'cutscenes': {'decent': {'count': 2, 'importance': 0.0},
#   'great': {'count': 2, 'importance': 1.2498}},
#  'conditions': {'good': {'count': 2, 'importance': 0.8808}},
#  'mart': {'local': {'count': 2, 'importance': 0.0}},
#  'seller': {'legit': {'count': 2, 'importance': 0.0}},
#  'nurf': {'pre': {'count': 2, 'importance': 0.0}},
#  'entries': {'previous': {'count': 2, 'importance': 0.0}},
#  'writing': {'excellent': {'count': 2, 'importance': 1.1438}},
#  'mercs': {'disposable': {'count': 2, 'importance': 0.0}},
#  'attack': {'basic': {'count': 2, 'importance': 0.0}},
#  'variance': {'extreme': {'count': 2, 'importance': 0.0}},
#  'normal': {'easy': {'count': 2, 'importance': 0.8808},
#   'regardless': {'count': 2, 'importance': 0.0},
#   'linked': {'count': 2, 'importance': 0.0},
#   'challenging': {'count': 2, 'importance': 0.3062}},
#  'steps': {'small': {'count': 2, 'importance': 0.0}},
#  'hell': {'steps': {'count': 2, 'importance': 0.0}},
#  'challenge': {'easier': {'count': 2, 'importance': -0.6504}},
#  'wake': {'real': {'count': 2, 'importance': 0.0}},
#  'looks': {'area': {'count': 2, 'importance': 0.0}},
#  'choice': {'male': {'count': 2, 'importance': 0.0},
#   'visually': {'count': 2, 'importance': 0.0}},
#  'terms': {'practical': {'count': 2, 'importance': 0.0}},
#  'stat': {'pure': {'count': 2, 'importance': 0.0},
#   'individual': {'count': 2, 'importance': 0.0},
#   'higher': {'count': 2, 'importance': 0.0},
#   'boring': {'count': 2, 'importance': -0.6364}},
#  'gems': {'worthless': {'count': 2, 'importance': -0.8808},
#   'best': {'count': 2, 'importance': 1.2738},
#   'better': {'count': 2, 'importance': 0.8808}},
#  'possible': {'maximum': {'count': 2, 'importance': 0.0}},
#  'vitality': {'possible': {'count': 2, 'importance': 0.0}},
#  'socket': {'available': {'count': 2, 'importance': 0.0}},
#  'slot': {'single': {'count': 2, 'importance': 0.0},
#   'specific': {'count': 2, 'importance': 0.0}},
#  'drive': {'hard': {'count': 2, 'importance': -0.2054}},
#  'file': {'corrupted': {'count': 2, 'importance': 0.0}},
#  'computer': {'new': {'count': 4, 'importance': 0.0}},
#  'actions': {'special': {'count': 2, 'importance': -0.6178}},
#  'channel': {'general': {'count': 2, 'importance': 0.0}},
#  'spot': {'sore': {'count': 2, 'importance': -0.7224},
#   'general': {'count': 2, 'importance': 0.0}},
#  'side': {'flip': {'count': 2, 'importance': 0.0},
#   'good': {'count': 2, 'importance': 0.8808},
#   'bad': {'count': 2, 'importance': -1.0846}},
#  'processor': {'old': {'count': 2, 'importance': 0.0}},
#  'laptop': {'standard': {'count': 2, 'importance': 0.0},
#   'older': {'count': 2, 'importance': 0.0},
#   'ago': {'count': 2, 'importance': 0.0}},
#  'on': {'low': {'count': 2, 'importance': -0.5464}},
#  'flaws': {'small': {'count': 2, 'importance': 0.0},
#   'biggest': {'count': 2, 'importance': 0.0},
#   'very_big': {'count': 2, 'importance': 0.0}},
#  'mind': {'open': {'count': 2, 'importance': 0.0},
#   'human': {'count': 2, 'importance': 0.0},
#   'creative': {'count': 2, 'importance': -0.6824}},
#  'expansions': {'extra': {'count': 2, 'importance': 0.0}},
#  '20s': {'low': {'count': 2, 'importance': -0.5464}},
#  'runes': {'even_longer': {'count': 2, 'importance': 0.0}},
#  'online': {'fine': {'count': 2, 'importance': 0.4046},
#   'massive': {'count': 2, 'importance': 0.0},
#   'dead': {'count': 2, 'importance': -1.2972}},
#  'cluster': {'big': {'count': 2, 'importance': 0.0}},
#  'hordes': {'unseen': {'count': 2, 'importance': 0.0}},
#  'rift': {'greater': {'count': 2, 'importance': 0.7224}},
#  'bueno': {'muy': {'count': 2, 'importance': 0.0}},
#  'chapter': {'second': {'count': 2, 'importance': 0.0}},
#  'movie': {'real': {'count': 2, 'importance': 0.0}},
#  'owners': {'disgruntled': {'count': 2, 'importance': 0.0}},
#  'ideal': {'mythical': {'count': 2, 'importance': 0.0}},
#  'gamers': {'responsible': {'count': 2, 'importance': 0.6364},
#   'solo': {'count': 2, 'importance': 0.0},
#   'hardcore': {'count': 2, 'importance': 0.0}},
#  'concerns': {'valid': {'count': 2, 'importance': 0.0}},
#  "rpg'ers": {'hardcore': {'count': 2, 'importance': 0.0}},
#  'cheats': {'dangerous': {'count': 2, 'importance': -0.9534}},
#  'storage': {'shared': {'count': 4, 'importance': 1.36},
#   'bigger': {'count': 2, 'importance': 0.0}},
#  'program': {'secondary': {'count': 2, 'importance': 0.0},
#   'esque': {'count': 2, 'importance': 0.0}},
#  'voodoo': {'sweet': {'count': 2, 'importance': 0.9176}},
#  'sequel': {'perfect': {'count': 2, 'importance': 1.1438}},
#  'run': {'long': {'count': 2, 'importance': 0.0}},
#  'ref': {'normal': {'count': 2, 'importance': 0.0}},
#  'battlechest': {'new': {'count': 2, 'importance': 0.0}},
#  'version</a': {'new': {'count': 2, 'importance': 0.0}},
#  'waypoints': {'nice': {'count': 2, 'importance': 0.843}},
#  'locations': {'new': {'count': 2, 'importance': 0.0}},
#  'mazes': {'random': {'count': 2, 'importance': 0.0}},
#  'customers': {'more_happy': {'count': 2, 'importance': 1.223}},
#  'delivery': {'fast!,seller': {'count': 2, 'importance': 0.0}},
#  'nephew': {'away': {'count': 2, 'importance': 0.0}},
#  'wow': {'awesome': {'count': 2, 'importance': 1.2498}},
#  'disks': {'anymore': {'count': 2, 'importance': 0.0}},
#  'setup': {'triple': {'count': 2, 'importance': 0.0},
#   'right': {'count': 2, 'importance': 0.0}},
#  'screen': {'extra': {'count': 2, 'importance': 0.0},
#   'big': {'count': 2, 'importance': 0.0}},
#  'special': {'black': {'count': 2, 'importance': 0.0}},
#  'mercy': {'complete': {'count': 2, 'importance': 0.0}},
#  'difficulties': {'higher': {'count': 2, 'importance': 0.0},
#   'fun': {'count': 2, 'importance': -0.8046},
#   'not_\n': {'count': 2, 'importance': 0.0},
#   'more_challenging': {'count': 2, 'importance': 0.4494},
#   'multiple': {'count': 2, 'importance': 0.0}},
#  'clicking': {'mindless': {'count': 2, 'importance': -0.8808}},
#  'playthrough': {'2nd': {'count': 2, 'importance': 0.0}},
#  'emails': {'similar': {'count': 2, 'importance': 0.0}},
#  'battle.net': {'pain': {'count': 2, 'importance': -1.0212}},
#  'message': {'useless': {'count': 2, 'importance': -0.843}},
#  'drugs': {'really_bad': {'count': 2, 'importance': -1.1698}},
#  'nightmare': {'normal': {'count': 4, 'importance': 0.0}},
#  'attention': {'close': {'count': 2, 'importance': 0.0}},
#  'digit': {'double': {'count': 2, 'importance': 0.0}},
#  'cache': {'hidden': {'count': 2, 'importance': 0.0}},
#  'yellow': {'better': {'count': 2, 'importance': 0.8808}},
#  'mouse': {'left': {'count': 2, 'importance': 0.0},
#   'right': {'count': 2, 'importance': 0.0}},
#  'frustration': {'battles': {'count': 2, 'importance': -0.7636},
#   'house': {'count': 2, 'importance': 0.0},
#   'needling': {'count': 2, 'importance': 0.0},
#   'sub': {'count': 2, 'importance': 0.0},
#   '-': {'count': 2, 'importance': 0.0}},
#  'dying': {'easily': {'count': 2, 'importance': 0.68}},
#  'monk': {'character': {'count': 2, 'importance': 0.0},
#   'easier': {'count': 2, 'importance': 0.843}},
#  'jeweler': {'worthwhile': {'count': 2, 'importance': 0.68},
#   'fun': {'count': 2, 'importance': 1.0212}},
#  'specialist': {'smith': {'count': 2, 'importance': 0.0}},
#  'mysteries': {'magic': {'count': 2, 'importance': 0.0}},
#  'chances': {'high': {'count': 2, 'importance': 0.0}},
#  'listing': {'fresh': {'count': 2, 'importance': 0.6364}},
#  'bid': {'high': {'count': 2, 'importance': 0.0},
#   'single': {'count': 2, 'importance': 0.0}},
#  'experiences': {'memorable': {'count': 2, 'importance': 0.0}},
#  'flavor': {'goodly': {'count': 2, 'importance': 0.0}},
#  'humans': {'real': {'count': 2, 'importance': 0.0},
#   'differently_everytime': {'count': 2, 'importance': 0.0}},
#  'downside': {'communication': {'count': 2, 'importance': 0.0}},
#  'generator': {'random': {'count': 4, 'importance': 0.0}},
#  'worlds': {'huge': {'count': 2, 'importance': 0.6364}},
#  'feeling': {'much_better': {'count': 2, 'importance': 0.8808},
#   'better': {'count': 2, 'importance': 0.8808}},
#  'upgrade': {'priced': {'count': 2, 'importance': 0.0},
#   'single': {'count': 2, 'importance': 0.0}},
#  '60': {'multiple': {'count': 2, 'importance': 0.0}},
#  'total': {'grand': {'count': 2, 'importance': 0.9176}},
#  'gears': {'better': {'count': 2, 'importance': 0.8808}},
#  'complaining': {'old': {'count': 2, 'importance': 0.0}},
#  'details': {'miniscule': {'count': 2, 'importance': 0.0},
#   'precise': {'count': 2, 'importance': 0.0}},
#  'evils': {'new': {'count': 2, 'importance': 0.0}},
#  'revamp': {'healthy': {'count': 2, 'importance': 0.8038}},
#  'impact': {'positive': {'count': 2, 'importance': 1.1148}},
#  'frequency': {'greater': {'count': 2, 'importance': 0.7224}},
#  'sections': {'separate': {'count': 2, 'importance': 0.0},
#   'different': {'count': 2, 'importance': 0.0}},
#  'cap': {'furthermore': {'count': 2, 'importance': 0.0}},
#  'setback': {'interest': {'count': 2, 'importance': 0.9176}},
#  'pace': {'slow': {'count': 2, 'importance': 0.0}},
#  'crap': {'online': {'count': 2, 'importance': 0.0}},
#  'graphic': {'better': {'count': 2, 'importance': -0.6824}},
#  'pools': {'stacking': {'count': 2, 'importance': 0.0}},
#  'setting': {'highest': {'count': 2, 'importance': 0.0},
#   'hard': {'count': 2, 'importance': -0.2054}},
#  'speakers': {'good': {'count': 2, 'importance': 0.8808}},
#  'paths': {'dif': {'count': 2, 'importance': 0.0}},
#  'ff13': {'stupid': {'count': 2, 'importance': -1.0534}},
#  'sin': {'original': {'count': 2, 'importance': 0.6364}},
#  'x': {'running': {'count': 4, 'importance': 0.0}},
#  'clicky': {'clicky': {'count': 2, 'importance': 0.0}},
#  'donkey': {'happy': {'count': 2, 'importance': 1.1438}},
#  'cain': {'soo': {'count': 2, 'importance': 0.0}},
#  'girlfriend': {'online': {'count': 2, 'importance': 0.0}},
#  'points': {'good': {'count': 2, 'importance': 0.8808}},
#  'path': {'laid': {'count': 2, 'importance': 0.0}},
#  'interaction': {'real': {'count': 2, 'importance': 0.0}},
#  'trade': {'good': {'count': 2, 'importance': 0.8808}},
#  'dlc': {'souls': {'count': 2, 'importance': 0.0}},
#  'enjoyment': {'better': {'count': 2, 'importance': 0.8808}},
#  'data': {'present': {'count': 2, 'importance': 0.0}},
#  'purchaser': {'verified': {'count': 2, 'importance': 0.0}},
#  'disappointing': {'little': {'count': 2, 'importance': 0.0}},
#  'expectation': {'high': {'count': 2, 'importance': 0.0}},
#  'activation': {'online': {'count': 2, 'importance': 0.0}},
#  'keys': {'hot': {'count': 2, 'importance': 0.0}},
#  'hum': {'ho': {'count': 2, 'importance': 0.0}},
#  'max': {'generous': {'count': 2, 'importance': 1.0212}},
#  'hunting': {'good': {'count': 2, 'importance': 0.8808}},
#  'laggy': {'little': {'count': 2, 'importance': 0.0}},
#  'commitment': {'giant': {'count': 2, 'importance': 0.0}},
#  'tons': {'magic': {'count': 2, 'importance': 0.0}},
#  'excitement': {'barely_contained': {'count': 2, 'importance': 0.0}},
#  'iv': {'sooner': {'count': 2, 'importance': 0.0}},
#  'physics': {'great': {'count': 2, 'importance': 1.2498}},
#  'rendition': {'proper': {'count': 2, 'importance': 0.0}},
#  'recipe': {'magic': {'count': 2, 'importance': 0.0}},
#  'stories': {'simpler': {'count': 2, 'importance': 0.0},
#   'dumbed': {'count': 2, 'importance': -0.68}},
#  'creatures': {'so_hard': {'count': 2, 'importance': -0.3522}},
#  'fray': {'huge': {'count': 2, 'importance': 0.6364}},
#  'lag': {'away': {'count': 2, 'importance': 0.0}},
#  'unforgivable': {'just_horrendous': {'count': 2, 'importance': -1.1718}},
#  'shortcoming': {'unforgivable': {'count': 2, 'importance': 0.0}},
#  'defect': {'huge': {'count': 2, 'importance': 0.6364}},
#  'mistake': {'major': {'count': 2, 'importance': 0.0}},
#  'measure': {'punitive': {'count': 2, 'importance': -1.0212}},
#  'excuse': {'pathetic': {'count': 2, 'importance': -1.1438}},
#  'cycle': {'endless': {'count': 2, 'importance': 0.0}},
#  'tables': {'poorly_designed': {'count': 2, 'importance': 0.0}},
#  'required': {'online': {'count': 2, 'importance': 0.0}},
#  'guide': {'nice': {'count': 2, 'importance': 0.843}},
#  'information': {'baseline': {'count': 2, 'importance': 0.0}},
#  'saga': {'great': {'count': 2, 'importance': 1.2498}},
#  '20': {'+': {'count': 2, 'importance': 0.0}},
#  'series': {'past': {'count': 4, 'importance': 0.0}},
#  'rest': {'subpar': {'count': 2, 'importance': 0.0}},
#  'skill': {'best': {'count': 2, 'importance': 1.2738}},
#  'software': {'random': {'count': 2, 'importance': 0.0}},
#  'pad': {'cool': {'count': 2, 'importance': 0.6364},
#   'stationary': {'count': 2, 'importance': 0.0}},
#  'patching': {'nightmare': {'count': 2, 'importance': 0.0}},
#  'site': {'3rd': {'count': 2, 'importance': 0.0}},
#  'windows': {'newly_created': {'count': 2, 'importance': 0.5}},
#  'installer': {'actual': {'count': 2, 'importance': 0.0}},
#  'account': {'normal': {'count': 2, 'importance': 0.0}},
#  'savy': {'normal': {'count': 2, 'importance': 0.0},
#   'tech': {'count': 2, 'importance': 0.0}},
#  'user': {'able': {'count': 2, 'importance': 0.0},
#   'savy': {'count': 2, 'importance': 0.0}},
#  'membership': {'monthly': {'count': 2, 'importance': 0.0}},
#  'face': {'ugly': {'count': 2, 'importance': -1.0212}},
#  'penalties': {'high': {'count': 2, 'importance': 0.0}},
#  'star': {'rage': {'count': 2, 'importance': -1.1148}},
#  'achievements': {'shared': {'count': 2, 'importance': 0.68},
#   'really_stupid': {'count': 2, 'importance': -1.1418}},
#  'lists': {'separate': {'count': 2, 'importance': 0.0}},
#  'mana': {'how_important': {'count': 2, 'importance': 0.4046}},
#  'type': {'separate': {'count': 2, 'importance': 0.0}},
#  'name': {'different': {'count': 2, 'importance': 0.0}},
#  'pool': {'very_small': {'count': 2, 'importance': 0.0}},
#  'regen': {'very_high': {'count': 2, 'importance': 0.0}},
#  'button': {'right': {'count': 2, 'importance': 0.0},
#   'left': {'count': 2, 'importance': 0.0},
#   'yes': {'count': 2, 'importance': 0.8038}},
#  'spellcaster': {'ranged': {'count': 2, 'importance': 0.0}},
#  'groups': {'automated': {'count': 2, 'importance': 0.0}},
#  'credit': {'main': {'count': 2, 'importance': 0.0}},
#  'symbols': {'chinese': {'count': 2, 'importance': 0.0}},
#  'zone': {'obscure': {'count': 2, 'importance': 0.0}},
#  'necromancers': {'enjoyable': {'count': 2, 'importance': 0.8808}},
#  'cast': {'single': {'count': 2, 'importance': 0.0}},
#  'pets': {'cast': {'count': 2, 'importance': 0.0}},
#  'grpahics': {'cartoony': {'count': 2, 'importance': 0.0},
#   'imo': {'count': 2, 'importance': 0.0}},
#  'sword': {'double_edged': {'count': 2, 'importance': 0.0}},
#  'nights': {'original': {'count': 2, 'importance': 0.6364}},
#  'print': {'smallest': {'count': 2, 'importance': 0.0},
#   'possible': {'count': 2, 'importance': 0.0}},
#  'glass': {'magnifying': {'count': 2, 'importance': 0.0}},
#  'faith': {'good': {'count': 2, 'importance': 0.8808}},
#  'while': {'little': {'count': 2, 'importance': 0.0}},
#  'monday': {'cyber': {'count': 2, 'importance': 0.0}},
#  'mile': {'extra': {'count': 2, 'importance': 0.0}},
#  '5000': {'atleast': {'count': 2, 'importance': 0.0}},
#  'pc': {'current': {'count': 2, 'importance': 0.0}},
#  'chants': {'religious': {'count': 2, 'importance': 0.0}},
#  'century': {'16th': {'count': 2, 'importance': 0.0}},
#  '98': {'damn_better': {'count': 2, 'importance': 0.1032}},
#  'makers': {'better': {'count': 2, 'importance': 0.8808}},
#  'iie': {'old': {'count': 2, 'importance': 0.0}},
#  'bar': {'green': {'count': 2, 'importance': 0.0}},
#  'shipping': {'fast': {'count': 1, 'importance': 0.0}}}

# %%
FOPs_df = pd.read_csv(wdir+chosen_game+"_parser_FOPs.csv",error_bad_lines=False)  # Creation of the dataframe 

FOPs_df["count"] = FOPs_df["count"]/2
FOPs_df["importance"] = FOPs_df["importance"]/2
FOPs_df["importance"] = FOPs_df["importance"]/FOPs_df["importance"].max()
FOPs_df["polarity"] = FOPs_df["importance"]/FOPs_df["count"]
FOPs_df["importance"]= abs(FOPs_df["importance"])
FOPs_df = FOPs_df.sort_values('importance', ascending=False)
FOPs_df=FOPs_df.reset_index(drop=True)
# maxCount = FOPs_df.iloc[0]["count"]
# FOPs_df = FOPs_df.loc[FOPs_df["count"] > maxCount/20]
# FOPs_df = FOPs_df.sort_values('importance', ascending=False)
print(FOPs_df.shape)
FOPs_df.head(50)
# Out:
# (1809, 5)
# b'Skipping line 1629: expected 4 fields, saw 5\n'
#        feature    opinion  count  importance  polarity
# 0         game      great   29.0    1.000000  0.034483
# 1         game       good   17.5    0.425282  0.024302
# 2         game        fun   18.0    0.406410  0.022578
# 3      reviews   negative    7.0    0.220907 -0.031558
# 4          fun      great    4.0    0.137931  0.034483
# 5         game    awesome    4.0    0.137931  0.034483
# 6     graphics       good    5.0    0.121509  0.024302
# 7     graphics     better    5.0    0.121509  0.024302
# 8   experience      great    3.0    0.103448  0.034483
# 9        items     better    4.0    0.097207  0.024302
# 10        gear     better    4.0    0.097207  0.024302
# 11       thing        bad    3.0    0.089774 -0.029925
# 12       thing       good    3.0    0.072905  0.024302
# 13       items       good    3.0    0.072905  0.024302
# 14        loot     better    3.0    0.072905  0.024302
# 15    features    awesome    2.0    0.068966  0.034483
# 16   starcraft    awesome    2.0    0.068966  0.034483
# 17    graphics      great    2.0    0.068966  0.034483
# 18       price      great    2.0    0.068966  0.034483
# 19        gear    awesome    2.0    0.068966  0.034483
# 20        game    funnest    2.0    0.066151  0.033076
# 21        game  beautiful    2.0    0.066151  0.033076
# 22        game        bad    4.0    0.065991 -0.016498
# 23        game    amazing    2.0    0.064661  0.032331
# 24     product  excellent    2.0    0.063116  0.031558
# 25        game   very_fun    2.0    0.061395  0.030697
# 26        idea        bad    2.0    0.059850 -0.029925
# 27         guy        bad    2.0    0.059850 -0.029925
# 28     reviews        bad    2.0    0.059850 -0.029925
# 29         bad        bad    2.0    0.059850 -0.029925
# 30      factor        fun    2.0    0.056351  0.028176
# 31      diablo        fun    2.0    0.056351  0.028176
# 32        time       free    2.0    0.056351  0.028176
# 33        game     better    4.0    0.054078  0.013519
# 34        game     boring    3.0    0.052676 -0.017559
# 35         fan       huge    3.0    0.052676  0.017559
# 36      review   original    3.0    0.052676  0.017559
# 37      system     flawed    2.0    0.052610 -0.026305
# 38       drops       poor    2.0    0.052610 -0.026305
# 39       games   favorite    2.0    0.050634  0.025317
# 40        game   favorite    2.0    0.050634  0.025317
# 41        game         ok    3.0    0.049001  0.016334
# 42       stuff       good    2.0    0.048604  0.024302
# 43        play       good    2.0    0.048604  0.024302
# 44       price       good    2.0    0.048604  0.024302
# 45     product  defective    2.0    0.048604 -0.024302
# 46      skills     better    2.0    0.048604  0.024302
# 47   equipment     better    2.0    0.048604  0.024302
# 48   successor     worthy    2.0    0.048604  0.024302
# 49     weapons       good    2.0    0.048604  0.024302
