# %% [markdown]
# # SETUP

# %%
import pandas as pd
import numpy as np
import nltk
import time
import spacy
import pickle
sp = spacy.load('en_core_web_md')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords

# %% [markdown]
# # Load data

# %%
# wdir="steam/"
# wdir="metacritic/"
wdir="AM_videogames/"
df = pd.read_pickle(wdir+"1_df.pkl")
print(df.shape)
print(df.groupby('game_title').review_id.nunique())
df = df.sample(frac=1).reset_index(drop=True) # random sampling and resetting index

df.head(50)
# Out:
# (2585, 4)
# game_title
# God of War III                    601
# Mario Kart                        472
# StarCraft II: Wings of Liberty    370
# The Last of Us                    549
# diablo III                        593
# Name: review_id, dtype: int64
#     review_id                      game_title  \
# 0      215323                  The Last of Us
# 1       63636                      Mario Kart
# 2       50502                      Mario Kart
# 3       51671                  God of War III
# 4       51595  StarCraft II: Wings of Liberty
# 5      215562                  The Last of Us
# 6       50386                      Mario Kart
# 7       65050                  God of War III
# 8      215206                  The Last of Us
# 9       65302                  God of War III
# 10     215515                  The Last of Us
# 11      51511  StarCraft II: Wings of Liberty
# 12     215357                  The Last of Us
# 13      72711                      diablo III
# 14      63645                      Mario Kart
# 15      59372                      diablo III
# 16      65223                  God of War III
# 17     215522                  The Last of Us
# 18      50191                      Mario Kart
# 19      59420                      diablo III
# 20     215490                  The Last of Us
# 21     215288                  The Last of Us
# 22      72790                      diablo III
# 23      64877  StarCraft II: Wings of Liberty
# 24     215697                  The Last of Us
# 25      72849                      diablo III
# 26      65478                  God of War III
# 27     215618                  The Last of Us
# 28      50310                      Mario Kart
# 29     215611                  The Last of Us
# 30      64913  StarCraft II: Wings of Liberty
# 31      72583                      diablo III
# 32      51495  StarCraft II: Wings of Liberty
# 33      50387                      Mario Kart
# 34      65544  StarCraft II: Wings of Liberty
# 35      50447                      Mario Kart
# 36      50230                      Mario Kart
# 37     215732                  The Last of Us
# 38      59519                      diablo III
# 39      59504                      diablo III
# 40     215629                  The Last of Us
# 41      59302                      diablo III
# 42     215602                  The Last of Us
# 43      50253                      Mario Kart
# 44     215378                  The Last of Us
# 45      51846                  God of War III
# 46      63594                      Mario Kart
# 47      65473                  God of War III
# 48      72667                      diablo III
# 49      50405                      Mario Kart
#
#                                           review_text  score
# 0      I got this as a gift for myself and I like it.    5.0
# 1   My 6 year old loves this game. Very kid freind...    5.0
# 2   I've been a LONG TIME Mario Kart fan since SNE...    5.0
# 3                                         Great game.    5.0
# 4   Fantastic game!  The game play wonderfully and...    5.0
# 5   Very happy with this game. It's extremely ente...    5.0
# 6   I was a big fan of Mario Kart for the Super NE...    5.0
# 7                                        EXCELLENT...    5.0
# 8   Really great game love it so much  story is aw...    5.0
# 9   This is a good game but I find it difficult to...    3.0
# 10                                     Excelent -game    5.0
# 11  Amazing Game!! The installation key was alread...    4.0
# 12                                          Excelente    5.0
# 13  At first I didn't like the online control of t...    5.0
# 14  I am very pleased with this purchase!  I remem...    5.0
# 15  I am still pissed off at myself for buying thi...    1.0
# 16  an epic conclution to the greatest video game ...    5.0
# 17                                               good    5.0
# 18                                         very nice.    5.0
# 19  My title says all. It is the worst game! I am ...    1.0
# 20  The product arrived in perfect condition, than...    5.0
# 21  story started off good then got weak. Controls...    2.0
# 22  This game was a huge disappointment for me. I ...    2.0
# 23                                works as advertised    5.0
# 24  All of the stories, hype, awards, and accolade...    5.0
# 25  You should be aware that since you cannot save...    1.0
# 26  This game just blown every other game out of t...    5.0
# 27  the game is no doubt one of the best of its ty...    4.0
# 28  Even now, years after its release, this game i...    5.0
# 29  Loved, loved, loved the game! Very high qualit...    5.0
# 30  This game was fun to play for me and a buddy i...    5.0
# 31  A good Action-RPG that was initially held back...    4.0
# 32                 cant play worthless waste of money    1.0
# 33  My husband and I have alot of fun playing this...    4.0
# 34  I've had fun going through the first part of t...    4.0
# 35  This game is not the most challenging but is g...    4.0
# 36                                          excellent    5.0
# 37  This game is just about as close to perfection...    5.0
# 38  Played D2 all the way through many times.\n\nD...    5.0
# 39  There are a lot of negative reviews about this...    1.0
# 40  Have this title for PS3, had to see it on PS4....    5.0
# 41  Great RPG for anyone looking to spend time on ...    5.0
# 42            What else can I say. Best game, period.    5.0
# 43                                              Zoom!    4.0
# 44  I bought TLOU for the ps3, and now that I upgr...    5.0
# 45  Having mythology as the inspiration for the Go...    4.0
# 46                       Great Buy for the Grandkids!    5.0
# 47  KRATOS!!!!!!!!!!!!!!!!! long live the god of w...    5.0
# 48  Love this game!  Love joining family and frien...    5.0
# 49  This game is fun for the whole family, it's pr...    5.0

# %% [markdown]
# # Preprocessing reviews

# %% [markdown]
# ## split reviews in sentences + compute sentence polarities

# %%
from nltk import tokenize # del
from sentiment_polarity import * 
# nltk.download('punkt') # doesnt re download is exists ) 
from stopwords import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# %%timeit -n 1 -r 1 
sentences_df = extract_sentences(df)


sentences_df['vader_polarity'] = sentences_df["sentence"].apply(getVaderPolarity)


print(sentences_df.shape)
sentences_df.to_pickle(wdir+"2_df.pkl")

sentences_df.head(20)
# Out:
# 2585
# 100% processed
# (15252, 4)
#     review_id                      game_title  \
# 0      215323                  The Last of Us
# 1       63636                      Mario Kart
# 2       63636                      Mario Kart
# 3       50502                      Mario Kart
# 4       50502                      Mario Kart
# 5       50502                      Mario Kart
# 6       50502                      Mario Kart
# 7       50502                      Mario Kart
# 8       50502                      Mario Kart
# 9       50502                      Mario Kart
# 10      50502                      Mario Kart
# 11      50502                      Mario Kart
# 12      50502                      Mario Kart
# 13      50502                      Mario Kart
# 14      51671                  God of War III
# 15      51595  StarCraft II: Wings of Liberty
# 16      51595  StarCraft II: Wings of Liberty
# 17      51595  StarCraft II: Wings of Liberty
# 18      51595  StarCraft II: Wings of Liberty
# 19     215562                  The Last of Us
#
#                                              sentence  vader_polarity
# 0      I got this as a gift for myself and I like it.          0.6597
# 1                      My 6 year old loves this game.          0.5719
# 2   Very kid freindly and lots of fun... Lots of t...          0.8313
# 3   I've been a LONG TIME Mario Kart fan since SNE...          0.8854
# 4                     It's about darn time Nintendo!!          0.0000
# 5   The Mii feature is a very fun aspect of the Wi...          0.7640
# 6   Another great feature is the ONLINE PLAY - whi...          0.9619
# 7   Being able to race strangers worldwide is very...          0.9459
# 8   One poor feature for me and my friends is the ...          0.2112
# 9   The remote and nunchuck are surely the way to ...          0.6486
# 10  The unlockable characters, karts and motorcycl...          0.8537
# 11         The retro-levels are awesome, more please!          0.7897
# 12  Same with the weapons, the new ones are fun, b...          0.6187
# 13  Overall it's been a real joy to play - and I r...          0.8568
# 14                                        Great game.          0.6249
# 15                                    Fantastic game!          0.5983
# 16  The game play wonderfully and is a unique sett...          0.7430
# 17  I want the expansion (Hearts of the Swarm) but...          0.4215
# 18  A little known secret is that if you purchase ...          0.6124
# 19                         Very happy with this game.          0.6115

# %% [markdown]
# ## Stop words

# %%
# %%timeit -n 1 -r 1 # number of loop
sentences_df = pd.read_pickle(wdir+"2_df.pkl")

games_list=df['game_title'].unique()

proc_sent_df = remove_stop_prefixes(sentences_df,games_list)
print(proc_sent_df.shape)


proc_sent_df.to_pickle(wdir+"3_df.pkl")
proc_sent_df.head()
games_list
# Out:
# 100% processed       % processed    % processed    % processed
# (15252, 5)
# array(['The Last of Us', 'Mario Kart', 'God of War III',
#        'StarCraft II: Wings of Liberty', 'diablo III'], dtype=object)

# %% [markdown]
# ## POS + Lemmatization
# TB and WN, 30 sec for 20k sentences
# SP is way longer, 60x longer (30 min )

# %%
from POSLemma import *
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\basil\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# %%timeit -n 1 -r 1 # number of loop
POSLemmaChoice ="SP" # WN TB SP
proc_sent_df = pd.read_pickle(wdir+"3_df.pkl")


POSLemma_sent_df = POSLemma_extractor(proc_sent_df,POSLemmaChoice)


## Save POSLemma Dataframe
POSLemma_sent_df.to_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
print(POSLemma_sent_df.head(5))
print(POSLemma_sent_df.shape)
# Out:
# 7  % processed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b925b8989cc0> in <module>
#       4
#       5
# ----> 6 POSLemma_sent_df = POSLemma_extractor(proc_sent_df,POSLemmaChoice)
#       7
#       8
#
# ~\master2\tfe\code_final\POSLemma.py in POSLemma_extractor(proc_sent_df, POSLemmaChoice)
#      22             print(int(index/df_len*100) , " % processed", end="\r", flush=True)
#      23
# ---> 24         processed_sentence, POS_tags= POSLemmaFunction(POSLemmaChoice , row["processed_sentence"])
#      25 #         print(POS_tags)
#      26         POSLemma_sent_dic[index] = {'review_id' : row["review_id"],
#
# ~\master2\tfe\code_final\POSLemma.py in POSLemmaFunction(POSLem_choice, sentence)
#     107     if POSLem_choice == "WN": return WordNetPOSLemmatizer(sentence)
#     108     elif POSLem_choice== "TB": return TextBlobPOSLemmatizer(sentence)
# --> 109     elif POSLem_choice== "SP": return SpacyPOSLemmatizer(sentence)
#
# ~\master2\tfe\code_final\POSLemma.py in SpacyPOSLemmatizer(sentence)
#      90     #     ['tok2vec', 'tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']
#      91
# ---> 92     sentence= sp(sentence)
#      93     lemmatized_sentence = " ".join([word.lemma_ for word in sentence ])
#      94     tagList=[]
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     993                 error_handler = proc.get_error_handler()
#     994             try:
# --> 995                 doc = proc(doc, **component_cfg.get(name, {}))
#     996             except KeyError as e:
#     997                 # This typically happens if a component is not initialized
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\pipeline\transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\pipeline\transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\ml\tb_framework.py in forward(model, X, is_train)
#      29
#      30 def forward(model, X, is_train):
# ---> 31     step_model = ParserStepModel(
#      32         X,
#      33         model.layers,
#
# ~\miniconda3\envs\basic\lib\site-packages\spacy\ml\parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\with_array.py in forward(model, Xseq, is_train)
#      28 def forward(model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool):
#      29     if isinstance(Xseq, Ragged):
# ---> 30         return _ragged_forward(
#      31             cast(Model[Ragged, Ragged], model), cast(Ragged, Xseq), is_train
#      32         )
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\with_array.py in _ragged_forward(model, Xr, is_train)
#      88 ) -> Tuple[Ragged, Callable]:
#      89     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 90     Y, get_dX = layer(Xr.dataXd, is_train)
#      91
#      92     def backprop(dYr: Ragged) -> Ragged:
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\miniconda3\envs\basic\lib\site-packages\thinc\layers\maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# # Create FOPs and compute importance

# %% [markdown]
# ## FOPs extraction

# %%
from FOPs import *

# %%
FOPs_df = pd.read_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
FOPs_df.head()
# Out:
#    review_id  game_title                                           sentence  \
# 0      59465  diablo III          It's impossible to decide where to begin.
# 1      59465  diablo III  The only reason this game sold so well is beca...
# 2      59465  diablo III  The developers keep using this as some ridicul...
# 3      59465  diablo III                             Diablo III is garbage.
# 4      59465  diablo III  We only bought Diablo III because Diablo II wa...
#
#    vader_polarity                    processed_sentence  \
# 0          0.0000               impossible decide begin
# 1          0.9465  reason sell ii love brilliant gaming
# 2          0.2960     developer ridiculous sign success
# 3          0.0000                           iii garbage
# 4          0.5859           buy iii ii brilliant decent
#
#                                                 tags
# 0         [(impossible, a), (decide, n), (begin, v)]
# 1  [(reason, n), (sold, v), (ii, None), (loved, v...
# 2  [(developers, n), (ridiculous, a), (sign, n), ...
# 3                        [(iii, None), (garbage, n)]
# 4  [(bought, v), (iii, n), (ii, None), (brilliant...

# %%
# %%timeit -n 1 -r 1 # number of loop
"""
input: Dataframe of sentences with POS tags, chosen POS method and game title. 
Output: a dictionary of FOPs with their occurence and importance(occurence*sentence polarity) , structured as: 
        {"feature1": 
            {"opinion1": 
                { "count": value, 
                "importance":value } }
            {"opinion2": 
                { "count": value, 
                "importance":value } }
"""

POSLemmaChoice="SP"
FOPs_df = pd.read_pickle(wdir+"4_"+POSLemmaChoice+"_df.pkl")
# print(FOPs_df.groupby('game_title').review_id.nunique())
games_list=df['game_title'].unique()


print(games_list)
chosen_game="diablo III"


FOPs_game_dic = extract_all_FOPs(FOPs_df, chosen_game)

save_FOPs_dic_csv(FOPs_game_dic, wdir,chosen_game )

# %%
# FOPs_game_dic

# %% [markdown]
# ## count and importance FOPs results
# Can also select only negatives or only positive, select specific feature(s)

# %%
FOPs_df = pd.read_csv(wdir+chosen_game+"_FOPs.csv")  # Creation of the dataframe 

FOPs_df["count"]=FOPs_df["count"]/2
FOPs_df["importance"]=FOPs_df["importance"]/2
FOPs_df["polarity"] = FOPs_df["importance"]/FOPs_df["count"]
FOPs_df["importance"]= abs(FOPs_df["importance"])


FOPs_df = FOPs_df.sort_values('importance', ascending=False)



FOPs_df=FOPs_df.reset_index(drop=True)
# maxCount = FOPs_df.iloc[0]["count"]
# FOPs_df = FOPs_df.loc[FOPs_df["count"] > maxCount/20]
# FOPs_df = FOPs_df.sort_values('importance', ascending=False)
print(FOPs_df.shape)
FOPs_df.head(20)

# %%
sortir les 20-40 graphiques selon l'importance, 
tous les sauver  blabla

# %%
information retrieval

# %%
FOPs_df = FOPs_df.sort_values('count', ascending=False)
FOPs_df=FOPs_df.reset_index(drop=True)

FOPs_df.head(5)
